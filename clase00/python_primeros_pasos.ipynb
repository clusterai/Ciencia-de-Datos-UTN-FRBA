# %% [markdown]
# # Primeros pasos en python

# %% [markdown]
# **ClusterAI 2021
# Ciencia de Datos - Ingenieria Industrial UTN BA <br>
# Curso I5521 <br>
# Docente: Kevin Dobzewicz  <br>
# Autor: Martin Palazzo <br>
# Clase00: Primeros pasos Python**  <br>

# %% [markdown]
# ### Instrucciones y pasos a seguir para poder realizar la primer inmersión en python:

# %% [markdown]
# En este jupyter notebook se abordan las asignaciones para los primeros pasos en python. Se observarán las funciones básicas, familiarización con el sintaxis y práctica necesaria para poder continuar con las asignaciones de futuras clases. Aprender esta herramienta será util para desarrollar distintas aplicaciones de data science y analisis de datos. Te sugerimos fervientemente que sigas el objetivo de este código al ejecutarlo por completo (o hasta donde llegues).

# %% [markdown]
# **Objetivo de este codigo:** lo importante es poder ejecutarlo, tratar de leer el codigo e interpretar la sintaxis. Observar detalladamente el paso a paso para ganar nociones de como se escribe codigo en python. Fijense que dejamos muchas notas para que puedas seguir todas las acciones realizadas :). Asuman esta etapa como "aprender un idioma nuevo". Inicialmente sera un poco confuso, aunque a medida que pase el tiempo lo adoptaran y se sentiran mas comodos.

# %% [markdown]
# **Como ejecutar este archivo:** La manera en que se ejecuta cada celda de Jupyter es mediante "Shift + Enter" o con el boton de "play" que se encuentra en la barra superior. Una vez ejecutado todo el codigo, sientanse libres de modificar algunas variables a su gusto para ir obteniendo distintos resultados. Por ejemplo, crear matrices o vectores de distintas dimensiones, etc.

# %% [markdown]
# # Primeros pasos
# **Imprimir texto en pantalla (hola mundo)**

# %%
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# **Operaciones básicas con enteros**
# Antes de utilizar cualquier librería, python ya permite dentro de su sintaxis realizar algunas operaciones matematias con integers (enteros) o floats (reales).

# %%
(5+3)*10
# Out:
# 80

# %% [markdown]
# A la operación anterior podría guardarla en una variable (llamada "cuenta"), para que quede en memoria y asi poder acceder a su contenido en el futuro.

# %%
# guardamos la operacion en la variable "cuenta"
cuenta = (5+3)*10

# %%
# accedemos al interior de la variable "cuenta" para asegurarnos que se guardo bien los datos del resultado
cuenta
# Out:
# 80

# %%
# el comando "type" nos permite poder saber que tipo de formato de dato esta guardado en la variable en cuestion
type(cuenta)
# Out:
# int

# %% [markdown]
# ## Librería Numpy

# %% [markdown]
# **Importar librerias:**
# Python posee ya muchas librerías con funciones específicas según la tarea que querramos realizar. Existen librerías de cálculo, de visulización, de estadística, procesamiento de señales, de algebra lineal y de redes neuronales artificiales (entre muchas mas). Nuestro primer paso será importar **Numpy**, una importante librería que nos permitirá realizar operaciones numéricas con matrices, vectores y escalares.

# %%
# importamos la librería Numpy
import numpy as np

# %% [markdown]
# **Primeras operaciones con Numpy**:
# Con "np. + comando" de numpy podremos realizar muchas operaciones. Como crear una matriz de 2x2 de ceros.

# %%
# creamos la matriz de 2x2 llena de ceros con el comando np.zeros()
nula = np.zeros((2,2))

# %%
# La visualizamos en pantalla
nula
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
# con type nos fijamos que tipo de variable es "nula"
# python permite muchos tipos de variables, en este caso es un numpy array
type(nula)
# Out:
# numpy.ndarray

# %%
# con np.shape() podremos saber las dimensiones de la variable en cuestion
np.shape(nula)
# Out:
# (2, 2)

# %%
np.shape(cuenta)
# Out:
# ()

# %% [markdown]
# Las posiciones en python comienzan en 0. Entonces si tenemos un elemento de 4 posiciones, la primera sera la posicion 0 y la ultima posicion sera la 3. Cuando tenemos matrices (arrays)

# %%
# si quisieramos acceder al elemento 0,0 de nula 
nula[0,0]
# Out:
# np.float64(0.0)

# %% [markdown]
# Una vez declarada en python, podemos modificar alguno de los elementos de la matriz (numpy array) nula.

# %%
# por ejemplo el de la posicion 1,0
nula[1,0] = 4

# y tambien modificamos la posicion 0,1
nula[0,1] = 10

# %%
# imprimimos la matriz nula en pantalla para observar la modificacion realizada
nula
# Out:
# array([[ 0., 10.],
#        [ 4.,  0.]])

# %% [markdown]
# podriamos realizar operaciones logicas y obtener resultados "booleanos" (True or False). Por ejemplo, preguntamos que elementos son mayores a cero.

# %%
nula_mayor_cero = nula > 0

# %%
nula_mayor_cero
# Out:
# array([[False,  True],
#        [ True, False]])

# %% [markdown]
# Calculamos raiz cuadrada de todos los elementos de la matriz nula con el comando np.sqrt(). SQRT significa square root en ingles.

# %%
# podriamos calcular la raiz cuadrada de todos los elementos de nula con "np.sqrt()"
raiz_cuad = np.sqrt(nula)
raiz_cuad
# Out:
# array([[0.        , 3.16227766],
#        [2.        , 0.        ]])

# %% [markdown]
# con el comando de python de doble * se realiza el cuadrado del elemento en cuestion

# %%
# observamos que si a raiz_cuad la afectamos por el cuadrado obtenemos nuevamente nula
raiz_cuad**2
# Out:
# array([[ 0., 10.],
#        [ 4.,  0.]])

# %%
type(raiz_cuad)
# Out:
# numpy.ndarray

# %% [markdown]
# Numpy tambien nos permite crear matrices de la dimension que querramos con numeros aleatorios mediante el comando "np.random.rand()".

# %%
# creamos un array de 3x3 con todos sus elementos completados nros aleatorios de una distribución uniforme 
array_uniform = np.random.rand(3,3)
array_uniform
# Out:
# array([[0.56701462, 0.77301325, 0.24469137],
#        [0.97577293, 0.22677448, 0.66143479],
#        [0.72146877, 0.86481308, 0.70837692]])

# %% [markdown]
# Podemos tambien crear vectores, solamente especificando una sola dimension.

# %%
# generamos un vector de 10 posiciones completados desde nros. aleatorios de una dist. uniforme
vector_uniform = np.random.rand(10)
vector_uniform
# Out:
# array([0.09835932, 0.09634593, 0.81607794, 0.37583337, 0.95386918,
#        0.28296228, 0.90995445, 0.46678298, 0.91477384, 0.78366652])

# %%
np.shape(vector_uniform)
# Out:
# (10,)

# %%
type(vector_uniform)
# Out:
# numpy.ndarray

# %% [markdown]
# Trasponer un numpy array con ".T" al final

# %%
# vamos a transponer la matriz array_uniform
array_uniform_t = array_uniform.T
array_uniform_t
# Out:
# array([[0.56701462, 0.97577293, 0.72146877],
#        [0.77301325, 0.22677448, 0.86481308],
#        [0.24469137, 0.66143479, 0.70837692]])

# %% [markdown]
# Calcular la inversa de una matriz (en formato numpy array) con el comando np.linalg.inv()

# %%
# podemos tambien calcularle la inversa a la matriz array_uniform
array_uniform_inv = np.linalg.inv(array_uniform)
array_uniform_inv
# Out:
# array([[ 1.7713574 ,  1.44667602, -1.96268072],
#        [ 0.92151551, -0.96936485,  0.58681294],
#        [-2.92911534, -0.28997581,  2.69422856]])

# %% [markdown]
# Calcular el producto de dos matrices con np.dot

# %%
# podemos calcular el producto punto (dot product) entre array_uniform y array_uniform_inv
array_uniform_dot = np.dot(array_uniform, array_uniform_inv)
array_uniform_dot
# Out:
# array([[ 1.00000000e+00, -7.50685818e-17,  1.16266096e-16],
#        [ 3.46263059e-17,  1.00000000e+00,  9.85192414e-18],
#        [-1.34432857e-16,  5.90245631e-17,  1.00000000e+00]])

# %% [markdown]
# Crear una matriz con valores determinados por el usuario

# %%
# tambien podriamos crear una nueva matriz con datos ingresados 
a=np.array([[1  ,-4],[12 , 3]])
a
# Out:
# array([[ 1, -4],
#        [12,  3]])

# %% [markdown]
# ## Distribuciones de probabilidad con numpy

# %% [markdown]
# Generamos un vector cuyas posiciones sean numeros aleatorios provenientes de una distribucion normal con media y desvio standard determinado.

# %%
# declaramos las variables numericas "mu" y "sigma"
mu = 0
sigma = 0.1 
# con las variables declaradas generamos un vector de 1000 posiciones
# cada posicion es un numero aleatorio extraido de una distribucion normal
normal_sample = np.random.normal(mu, sigma, 1000)

# %%
# si quisieramos ver las dimensiones del vector usamos el comando np.shape
np.shape(normal_sample)
# Out:
# (1000,)

# %%
# si quisieramos saber que tipo de variable es "normal_sample" usamos el comando type
type(normal_sample)
# Out:
# numpy.ndarray

# %%
# si quisieramos saber el valor de la posicion 51 del vector "normal_sample"
normal_sample[50]
# Out:
# np.float64(-0.009389349526060096)

# %%
# podemos redondear el valor obtenido en la celda anterior con "np.round()"
# le pedimos 4 decimales
np.round(normal_sample[50],4)
# Out:
# np.float64(-0.0094)

# %%
# imprimimos en pantalla el vector correspondiente
normal_sample
# Out:
# array([-1.75641575e-01, -4.24842873e-02, -8.89067871e-02, -9.94621941e-03,
#        -9.52121640e-02, -1.33410193e-01,  8.46155392e-02, -1.33110943e-01,
#         2.12972373e-01, -1.11832474e-01, -1.02257589e-01,  5.04155511e-02,
#        -1.25709499e-03, -8.46363756e-02, -1.46540255e-01, -4.64167584e-03,
#        -3.23401301e-02, -1.43231564e-01, -8.86634567e-02, -1.09908284e-01,
#        -6.86779196e-02,  1.83756255e-01,  7.17913431e-02, -5.39637078e-02,
#        -1.22111599e-01,  5.52875950e-03, -7.53254892e-03, -1.94294180e-01,
#        -1.09765407e-01, -1.91033395e-01, -1.51661410e-01,  1.60069530e-01,
#        -6.75397999e-02, -6.28057184e-02,  5.14854800e-02, -4.98622086e-02,
#         4.09224516e-02, -6.21590710e-03, -2.31306663e-02,  7.25825545e-02,
#         2.75318987e-01, -4.59874466e-02, -1.57592349e-01, -7.57308149e-02,
#         6.29349531e-02, -6.62011213e-03, -6.60641532e-02,  1.25048696e-01,
#         4.78537930e-02, -1.42679559e-01, -9.38934953e-03, -7.32998746e-02,
#         1.08241885e-01, -1.01225996e-02, -1.92900187e-01,  1.91448114e-01,
#         1.94663682e-02, -5.53091003e-02, -7.23355223e-02,  1.17884388e-01,
#         1.91922644e-02,  1.03338762e-01,  8.64957404e-02,  1.60930008e-01,
#         2.02671757e-02, -3.87382305e-02, -1.66324649e-01, -9.31208007e-03,
#        -1.69460668e-01, -3.94290519e-02, -2.39117834e-02,  4.93976510e-02,
#         1.09456618e-01, -8.82301991e-02, -1.80474529e-01,  2.46377196e-03,
#         6.00925550e-02, -2.45387615e-02, -9.51878138e-02,  1.26545087e-01,
#         3.16945610e-02, -8.86780185e-02, -1.17253645e-01, -3.69983665e-02,
#         6.42484769e-02,  6.01805459e-03,  2.92532712e-02, -7.59601212e-02,
#        -1.71401454e-02,  1.15617862e-01,  1.63467076e-03, -6.42987636e-02,
#         6.82438088e-02,  3.12219762e-02, -8.06909572e-02,  9.59530985e-02,
#        -1.81457383e-01, -2.38058300e-02,  6.38872977e-02,  5.70623687e-02,
#         2.09445191e-01, -3.56546442e-02, -1.01899021e-01, -1.38478404e-01,
#         8.94395757e-03,  5.46295755e-02, -2.95890395e-02, -1.55589634e-01,
#         3.93867248e-03,  7.66766553e-02,  1.26598005e-01,  7.76570906e-02,
#         1.47992375e-01,  1.76584115e-04,  2.40781529e-02,  9.80289720e-02,
#        -2.61260488e-02, -1.09947189e-01,  6.94027953e-02, -2.18561475e-01,
#         9.29921783e-03, -1.13413915e-01, -1.06686595e-01, -5.91318920e-02,
#        -7.86256640e-02,  5.91988396e-02, -7.85619711e-02,  1.02372267e-02,
#        -1.27779512e-01, -2.25618988e-01, -1.52674719e-02, -1.45618746e-01,
#         1.18931554e-01,  6.17884540e-02, -1.03131147e-01,  1.43659887e-01,
#        -1.81359393e-02,  5.84304888e-02, -1.17584802e-01, -4.33989389e-02,
#        -5.54455184e-02,  9.98039396e-02, -1.86277390e-03,  3.82111567e-02,
#        -1.46907474e-01, -4.93563691e-02, -8.60903724e-02, -1.75259176e-01,
#         9.85758189e-02,  3.63253893e-02,  6.74886427e-02,  1.18511495e-01,
#        -1.35745072e-01, -1.48273866e-01, -1.01361575e-01,  3.87014510e-02,
#        -1.04183153e-01, -1.58030239e-02, -9.17599348e-02, -5.57276930e-02,
#        -9.59834735e-02, -3.07235532e-02, -2.83206082e-01, -3.48454595e-02,
#        -8.65636067e-03,  4.00916057e-02,  6.98076802e-02, -1.88387652e-01,
#         6.07324911e-02, -2.80392699e-01, -2.06195853e-01, -1.59069022e-01,
#        -9.29586743e-03, -4.08425394e-03,  1.29330989e-01,  9.86866989e-03,
#         2.15049030e-03,  4.62269458e-02,  3.09531440e-02,  1.83455762e-01,
#        -1.52317371e-01,  2.75353475e-02,  7.77012570e-02,  1.25986905e-02,
#        -1.62466977e-01,  1.35349645e-01, -2.33616301e-02, -5.21449225e-02,
#         1.55885068e-01,  2.26023299e-02,  9.33861453e-02,  9.63197442e-02,
#        -4.18892088e-02, -9.76666382e-02,  1.27701402e-01,  5.41758414e-02,
#        -1.51005991e-01, -2.12400059e-02, -5.41611650e-02, -3.22957883e-03,
#        -1.09918615e-01,  9.52329081e-03, -2.07915262e-01,  8.85417845e-03,
#         1.12358334e-01,  7.76191562e-02, -8.37537371e-02,  1.72485454e-02,
#         1.35168432e-01, -1.61545843e-01,  1.18617029e-01, -8.16146409e-02,
#         8.61290604e-02, -1.74175767e-01,  7.30177535e-02,  1.12052053e-01,
#         1.25889090e-01, -3.98472127e-03, -8.04082851e-03,  1.68021014e-01,
#         9.86464493e-02, -3.15754715e-03,  2.09595621e-01, -1.38172981e-02,
#         1.60047409e-03, -6.93819766e-02,  7.87141568e-02, -1.14441330e-01,
#         1.15109150e-01,  1.99909630e-01,  2.47368546e-02,  1.04584604e-01,
#        -2.60456403e-02, -1.09302858e-01,  4.64234953e-02, -1.55830350e-02,
#         1.46242881e-02, -4.62695755e-03, -1.33402478e-01, -1.31671532e-01,
#        -1.69120561e-01,  1.11867339e-01, -4.89225144e-02,  4.59197472e-02,
#        -8.86300858e-04,  5.11283215e-02,  1.27428519e-01, -1.37297520e-01,
#        -8.70867675e-02,  1.25492157e-01,  1.28735244e-01, -7.04410530e-02,
#         1.43977175e-01,  4.73929651e-02,  1.05419549e-01, -6.94478283e-02,
#        -7.07258739e-02, -8.54980136e-02,  5.38672482e-02,  1.30214343e-02,
#        -1.13376961e-01, -8.57906173e-02,  1.15599620e-01,  6.75622461e-02,
#        -9.83101442e-02, -1.15664466e-01,  5.83601156e-02,  3.81247860e-02,
#         2.16800472e-01,  1.90835409e-04, -4.81657257e-02,  1.37599597e-01,
#         3.28206785e-02, -8.86978515e-02, -3.74670186e-03,  5.09736847e-03,
#        -9.27896241e-02, -1.05117551e-01, -2.33576947e-02,  6.31480055e-02,
#        -5.58886508e-02, -4.37686542e-02, -8.92275146e-02, -1.50897229e-02,
#         2.93825187e-04, -2.76687795e-02, -4.22943946e-02,  5.60401441e-02,
#         3.09440902e-02,  4.85297206e-02, -1.00494163e-01, -5.36204346e-02,
#        -8.21901445e-02, -8.26391839e-02,  1.41956762e-01, -1.27069077e-01,
#        -7.57063774e-02, -5.06040654e-02, -1.15649338e-01,  6.14861057e-02,
#         8.49088658e-02,  2.05069008e-02,  1.11727818e-01, -5.98527928e-02,
#         1.76465808e-01,  7.10058512e-02,  4.83836535e-02,  2.16189100e-02,
#         2.81185525e-02, -4.15489389e-02,  1.09510633e-02, -8.12310170e-02,
#         1.60719179e-01, -1.10333385e-02,  7.88648087e-02,  9.06089406e-02,
#         7.86048699e-02, -4.23133138e-02, -1.07844393e-01,  5.87290186e-02,
#        -3.94175057e-03,  2.66259518e-01,  1.69736979e-01, -2.87507498e-02,
#         8.67523250e-02,  1.50405444e-02, -5.48756987e-02,  1.65286459e-01,
#        -6.11001588e-02, -8.66133568e-02,  7.94377438e-03,  4.45947539e-02,
#        -1.95201045e-02,  1.13338679e-01, -1.06312641e-01,  1.77562056e-02,
#        -2.17685554e-01,  1.88158140e-01, -1.47441019e-02,  2.05846689e-01,
#         1.03218471e-01, -6.54644353e-02,  1.68081970e-01,  1.10331234e-01,
#        -5.20866349e-02, -1.08045905e-02,  4.31572337e-02,  1.31955308e-02,
#         9.76063588e-02, -1.19760629e-01,  9.65253829e-02, -1.81970079e-02,
#        -7.45320044e-02,  4.67400353e-02,  9.42497483e-02, -8.31073864e-02,
#         1.49392068e-01, -1.68368037e-01, -1.08974353e-01,  1.85806949e-01,
#        -2.41517601e-01,  3.57927789e-02, -4.05861167e-02,  2.44402782e-01,
#         5.09785341e-03, -1.70686711e-01, -1.36632779e-01,  1.13407024e-03,
#         8.10632294e-02,  8.37020122e-02, -1.32502776e-01,  2.12279680e-01,
#        -1.58767148e-01, -6.00689967e-02, -4.63361767e-03,  7.01174742e-02,
#         9.46240368e-02, -3.96432171e-02,  1.17578623e-01, -1.54822824e-01,
#        -1.74703573e-02, -1.72634617e-02,  6.49979345e-02, -1.27741289e-01,
#        -7.93976614e-02, -1.07049959e-01,  4.03342153e-02,  1.21414249e-01,
#        -7.66897185e-02,  5.28761833e-02,  3.89240160e-03, -4.83615939e-03,
#         6.88704814e-02, -8.82831081e-02,  1.09441518e-01, -8.40954749e-03,
#         9.68364592e-04,  2.46574513e-01,  1.68075054e-01,  1.04010648e-01,
#        -3.43224977e-02,  2.05922416e-01,  1.20297934e-01, -5.49143336e-02,
#         7.21549573e-02, -5.80340347e-02, -7.80162044e-03, -1.25540706e-01,
#        -1.71554330e-02,  2.35440702e-02, -1.03733878e-01,  1.36293764e-01,
#        -1.52037815e-02, -1.54043510e-02, -3.45238512e-02,  1.54317785e-01,
#        -1.35835040e-01,  8.28102782e-02,  4.27745752e-02, -2.84209317e-02,
#        -1.27184865e-01, -7.34889504e-02, -1.35369263e-01,  1.52775258e-01,
#         1.64978105e-01, -9.65907498e-02, -3.50302497e-02,  1.16458184e-01,
#        -1.84417124e-01,  1.14193300e-01, -1.15352378e-02,  1.01485303e-01,
#        -7.09265238e-02, -8.11885220e-02,  3.25795261e-02,  1.10404627e-01,
#        -4.51275369e-02, -9.82313196e-02, -4.74525118e-02,  1.16353991e-01,
#        -4.18182974e-04,  8.98956733e-03, -1.92189325e-01,  1.06848773e-03,
#         1.45154064e-01,  3.56944499e-02, -3.31066460e-02,  1.57645696e-01,
#        -1.79137777e-02, -3.55646028e-02,  4.27128729e-03, -4.21000597e-02,
#         5.24977800e-02, -1.55547834e-01,  4.89838371e-02,  3.68000182e-02,
#        -1.80784843e-01,  6.34132802e-02,  1.41857731e-01, -2.89591063e-02,
#         4.32883491e-02,  7.95049091e-02, -2.70979664e-02, -1.86707326e-01,
#         1.95162558e-01, -4.85693089e-02,  2.16804957e-01,  7.75064509e-02,
#        -8.50372760e-02, -1.92217033e-01,  2.21614385e-02, -1.37034765e-02,
#        -7.85596754e-02,  7.70062495e-02,  1.20808654e-01, -6.46582109e-02,
#         2.16902660e-01, -1.22431281e-01,  1.63764608e-01, -9.31822440e-03,
#         1.12537582e-01, -5.27809108e-02,  2.90435866e-02,  4.47031997e-02,
#        -1.39367571e-01,  2.03609273e-02, -1.45538213e-01,  1.77013382e-02,
#        -4.37819522e-02,  4.15069979e-02, -3.15714601e-02, -1.70372230e-01,
#        -1.95594231e-01,  7.83810565e-02, -2.74271845e-02,  8.32658669e-02,
#        -2.27150586e-01,  6.05792862e-02,  7.94869999e-02,  1.09408410e-01,
#        -2.86704879e-03,  1.36320500e-02, -7.14134211e-02, -3.27888519e-02,
#        -7.93753595e-02, -7.16361806e-03, -1.78304917e-02,  9.45080566e-02,
#         7.57141697e-02,  1.06305576e-01,  2.93981396e-02, -8.20575349e-02,
#        -4.51539899e-02,  2.84246231e-02, -5.25092245e-02,  1.23034728e-02,
#         8.83632386e-02, -5.71598339e-02,  7.54347654e-02, -1.64709977e-02,
#        -4.05219938e-02,  9.68928576e-02,  1.46038885e-01,  1.33278559e-01,
#         9.08742014e-03, -8.23266688e-02,  1.33038096e-03, -1.02031951e-01,
#        -1.82139563e-01,  3.31298930e-02, -6.23267796e-03, -2.55336573e-01,
#        -6.99297076e-02, -9.74254701e-02,  1.26910665e-01,  1.86666534e-01,
#        -1.33824706e-02, -4.00532492e-02, -3.25071194e-02,  5.01735326e-02,
#        -3.89859529e-02,  5.36995664e-02,  1.84776307e-01, -1.63140329e-01,
#        -5.55262247e-03,  5.73747845e-02,  9.70117705e-03, -1.73152903e-02,
#        -2.21443299e-02,  3.30584993e-02,  2.25925827e-01, -1.10079784e-01,
#        -1.17545830e-01, -2.04796507e-02,  3.07114920e-02, -5.43806677e-02,
#        -2.71652493e-02,  1.64139641e-02, -5.54536618e-02,  8.03761042e-03,
#        -4.82573238e-03, -1.44988007e-01,  1.57019890e-01,  3.08339740e-02,
#        -2.06947139e-01, -2.51592189e-02, -1.71170042e-01,  5.08582355e-02,
#        -3.34365870e-02,  6.42756551e-02,  2.45484729e-02,  3.24343639e-02,
#        -1.06465524e-01,  1.72229701e-02, -2.53140268e-02,  1.30694154e-01,
#         1.22974086e-02, -1.90042066e-02, -2.32587469e-02,  6.83075560e-02,
#         9.27340450e-02, -8.36288575e-02, -5.04933193e-02,  5.95486432e-02,
#        -1.09033108e-01,  4.81349701e-02,  5.76627761e-02, -2.87882687e-02,
#         5.03122352e-02, -9.72876645e-02, -3.23689875e-03,  4.91789484e-02,
#         1.02968319e-01, -1.10850430e-01, -2.04925557e-01,  4.80097878e-02,
#         3.33608856e-02, -5.57882461e-02, -1.11923243e-01,  2.16235629e-01,
#         1.87755019e-01, -3.14743565e-02, -7.49669372e-03,  1.89206779e-01,
#         1.25551621e-02,  5.35498137e-02, -2.05660789e-02,  4.35965301e-02,
#        -6.72084093e-02, -1.08294225e-01, -1.70860354e-02,  1.33369164e-01,
#        -1.37375981e-01,  4.91106399e-02, -3.41239285e-03, -2.68095933e-02,
#         6.84080270e-02, -8.25729765e-02,  1.04942360e-01, -7.25834462e-02,
#        -3.60013835e-02,  5.37360188e-02, -3.41627172e-03,  1.08031024e-03,
#         4.23566340e-02, -3.21935017e-02, -4.82945552e-02,  1.31798955e-01,
#        -3.57133112e-02, -8.57889572e-02,  5.68841014e-02, -1.37362150e-01,
#         4.72870337e-02,  1.28557312e-01, -2.61755335e-02,  1.64405059e-01,
#         3.49264845e-01, -4.14011668e-02, -2.86967152e-01, -2.22621001e-02,
#         7.94004881e-03,  6.37297646e-02, -4.15238999e-02,  1.32902526e-02,
#        -8.67807662e-02, -3.65280703e-02, -1.30764063e-01,  1.40914519e-02,
#         1.16402203e-01, -3.83818020e-02, -1.10151056e-01, -2.22905904e-02,
#         3.52576638e-01,  1.46571917e-01,  5.74392986e-02, -4.18822063e-02,
#        -6.33919997e-02, -6.20433902e-02,  1.17380982e-01, -1.44084946e-03,
#         3.80964358e-02, -6.57441236e-02,  2.42463855e-02,  7.05658150e-02,
#         8.52857386e-02, -2.00562758e-02, -9.53402986e-02, -1.12011421e-02,
#         2.05146495e-02, -7.43012889e-04,  1.40498179e-02, -3.29014239e-01,
#        -1.44808496e-01,  1.30358828e-01,  8.25708337e-02,  3.60714705e-02,
#         5.26831019e-02, -2.83532253e-02, -1.53792843e-01,  3.72611329e-02,
#        -1.62034099e-01, -6.57288248e-02, -1.41472874e-02,  1.37173765e-03,
#        -6.53304476e-02,  3.63521033e-02,  6.46396233e-02, -3.52604759e-02,
#         1.71074538e-01, -7.71462052e-02, -4.83215416e-02,  1.08637557e-01,
#         9.53864577e-02,  8.58664207e-04,  2.48101359e-01,  1.66740152e-01,
#        -2.94420938e-02,  1.06439396e-02, -3.24106119e-02, -1.20975143e-01,
#         8.06075041e-03,  3.40634517e-02,  7.12132325e-02, -1.36356731e-01,
#         1.69539636e-01, -1.19874424e-01, -2.40294663e-02,  2.03744836e-01,
#        -7.22806838e-03,  4.16011525e-03, -1.42081168e-01, -9.95096970e-02,
#        -3.00113256e-02, -3.02361171e-02, -1.84627108e-02,  6.86779948e-02,
#         1.66624648e-01,  1.80401989e-01,  8.96260899e-02,  2.27115815e-01,
#         3.72361414e-02,  3.70927143e-02, -8.90572166e-02, -1.08176915e-01,
#         2.25704662e-02, -8.46503759e-02,  7.46298425e-02,  6.29167578e-02,
#         1.68633040e-01,  1.00004634e-01,  1.45107871e-01,  1.60996969e-01,
#        -6.04510326e-02, -7.21255557e-02, -1.43643923e-02, -3.22312890e-02,
#        -6.68571649e-02,  2.02373238e-01, -4.98978889e-02, -1.78262652e-02,
#        -2.37412200e-01,  1.44831725e-02,  2.33955600e-02,  8.61400720e-02,
#         1.46669873e-01, -1.10495541e-01, -1.49597229e-02,  2.57209810e-01,
#        -3.40008738e-02, -3.38964406e-02,  1.15627475e-02, -1.25099633e-01,
#        -3.96127685e-02, -5.87051869e-02, -8.33876431e-02, -1.12059584e-01,
#         5.36766367e-02,  1.88078361e-02,  1.28554785e-01,  1.74135765e-01,
#        -2.63295089e-02, -1.40070442e-01,  3.93166623e-02, -7.10374571e-02,
#         8.60854502e-02, -7.16012028e-03,  5.70924644e-02,  8.55354991e-03,
#         9.55411022e-02,  9.90587904e-02,  9.41542256e-02,  1.58909698e-01,
#         1.87615166e-01,  1.60447843e-01,  1.07377090e-01, -5.10184236e-02,
#        -8.26178608e-02, -2.20392676e-01, -5.09193013e-03, -4.94131226e-02,
#        -4.98995516e-03,  8.00878987e-02,  4.50862832e-02,  1.34764911e-01,
#        -8.78161465e-02,  4.73064581e-02, -2.36756944e-02, -1.03149859e-01,
#        -1.09732011e-01, -1.03837298e-01, -7.71100549e-02, -3.63541020e-02,
#        -2.02661003e-02, -4.93834435e-02,  1.33615689e-01, -7.51678833e-02,
#        -2.33921195e-01,  1.22885157e-01, -4.50185415e-02, -4.70934617e-02,
#         1.30477161e-01,  2.71969983e-02, -1.55402817e-01,  3.43409311e-02,
#        -1.48106052e-01,  8.56508579e-02, -9.19740209e-02, -4.43825521e-02,
#        -4.70733140e-02, -9.76142835e-02, -4.92453173e-03,  6.92982777e-02,
#        -1.18704227e-02, -2.02010232e-02,  5.99654869e-02,  7.14621900e-02,
#        -1.26805782e-01, -6.28527043e-02, -4.00089996e-02, -2.40539120e-01,
#        -1.66588335e-01, -1.50757605e-01,  1.04372131e-01, -1.61135061e-02,
#         6.35923590e-02,  5.27193298e-02,  1.29222468e-01,  5.14534234e-02,
#        -1.72883365e-02,  1.08095198e-01, -8.80920450e-02,  1.13780309e-01,
#        -3.09698769e-02, -5.09531696e-02,  1.90657939e-01,  1.55907599e-01,
#         1.05731354e-01,  1.57761705e-01, -1.54798920e-02, -7.88475334e-02,
#         5.54047679e-02,  4.40814535e-02, -4.69761735e-02, -5.83502356e-02,
#        -1.29262288e-01,  7.74594929e-02, -7.94502273e-03,  5.16526675e-02,
#         1.03217632e-01,  1.21914145e-01, -8.24521750e-02, -3.00142731e-02,
#         2.48212248e-02, -3.08007252e-02,  1.07157069e-01, -7.66165797e-02,
#         3.78724184e-02, -1.63898126e-01, -2.59771741e-02,  2.06477763e-01,
#        -1.03314650e-01, -7.57859114e-03,  9.31509944e-02, -3.50579279e-02,
#         9.40144219e-02,  9.39661180e-02, -1.30084595e-01, -5.83489760e-02,
#         1.01844232e-01, -2.34156089e-03,  1.20845319e-01, -3.04071763e-02,
#        -2.90880059e-02, -2.61016298e-02,  1.30703975e-02,  4.33039643e-02,
#        -4.07514611e-02, -9.74752619e-02,  7.63434689e-02, -1.99203822e-02,
#         9.02266837e-02,  2.89238330e-02,  6.63297230e-02, -9.60623756e-02,
#         2.80716068e-02, -2.22251012e-02, -6.14928262e-02,  6.48282301e-02,
#        -1.16897406e-01, -3.80075823e-02,  1.27289165e-01,  2.11174320e-02,
#        -1.22713785e-01, -2.20115926e-01, -9.28011864e-02,  8.45681649e-03,
#        -1.54927433e-02,  7.30088581e-02,  3.52423500e-02, -7.68075563e-02,
#         1.80938702e-01, -1.67365289e-01, -4.59096307e-02, -9.60971922e-02,
#        -8.23590709e-02, -1.36410375e-01,  6.65182286e-02,  4.07126398e-02,
#        -6.57975600e-02,  1.93471510e-01, -3.97689993e-02,  1.48580201e-01,
#        -5.55095281e-02, -1.53012018e-01, -7.72328255e-02,  7.38633961e-03,
#         1.14790799e-01,  1.58045535e-01, -3.14562963e-02,  2.64584320e-02,
#        -6.59655695e-02, -1.59641964e-01,  1.22625292e-01, -9.76670336e-02,
#        -1.29995841e-02,  1.24975427e-02, -2.26971921e-01, -1.73218445e-02,
#        -3.13199688e-02, -2.46121092e-01, -4.22622695e-02, -2.58758612e-01,
#         1.51858548e-02,  2.30252350e-01, -4.56320561e-03,  5.13710623e-02,
#        -6.52664152e-02, -3.71554493e-03, -6.94108838e-02, -1.32137075e-01,
#         1.11666531e-01, -4.41841587e-02,  1.23872156e-01, -7.96292740e-03,
#        -2.90681210e-02, -1.02340860e-01, -4.73088999e-03,  5.69030045e-02,
#         5.06857143e-02, -1.53101545e-01, -2.55838912e-02, -1.12693943e-02,
#         3.61516190e-02, -1.87709140e-04, -7.44565933e-02,  8.55915130e-02,
#         2.76925145e-02, -4.89769224e-02,  1.45594604e-01, -1.11360734e-01,
#         1.90016814e-02,  1.04192739e-01, -3.24797064e-02,  1.31185688e-01,
#         3.55083934e-02,  8.46620642e-03,  2.41803966e-03, -1.66402534e-02,
#        -8.33205482e-02, -7.23953658e-02,  1.14080406e-01, -1.51654077e-01,
#        -2.72730402e-02,  1.46848245e-01,  1.25741586e-01,  5.86834708e-02,
#         7.56152400e-02,  4.84075850e-02,  5.59143206e-02, -1.48714377e-01,
#        -1.03303200e-01, -8.51752573e-02, -1.57446622e-01,  3.54611902e-02,
#        -1.06876790e-02, -1.17004105e-02,  4.97269967e-02,  1.13860365e-02,
#         2.61880094e-02, -1.27445357e-01, -6.05623264e-02,  1.03257979e-01,
#         2.24023413e-01,  2.52611811e-02, -3.19294351e-03,  1.82292680e-01,
#         1.09068839e-01,  1.05635301e-01,  1.66590943e-02,  1.81796076e-01])

# %% [markdown]
# ## Visualizaciones con librerías Matplotlib y Seaborn
# Ambas son para realizar visualizaciones. Existen muchas formas de visualizar datos estructurados en un vector o matriz. Los mas comunes son los histogramas, los mapas de calor, etc.

# %%
# importamos las librerias que nos serviran para visualizar
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Con "sns.distplot()" seaborn nos permite poder realizar un histograma y una aproximacion a la distribución de los datos en cuestion. En este caso realizaremos el distplot con el vector "normal_sample".

# %%
# generamos el distplot
sns.distplot(normal_sample)
plt.title("histograma del vector 'normal_sample' ")
plt.xlabel("valores de la variable aleatoria muestreada")
plt.ylabel("densidad de cada valor muestreado")
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_30316\309278116.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normal_sample)

# %% [markdown]
# Creamos otro vector proveniente de una normal con distinta media y desvio standard

# %%
# si generamos otro vector "normal_sample_2" con otra media y otro desvio standard
mu_2 = 0.5
sigma_2 = 0.2
# con las variables declaradas generamos un vector de 1000 posiciones
# cada posicion es un numero aleatorio extraido de una distribucion normal
normal_sample_2 = np.random.normal(mu_2, sigma_2, 1000)

# %%
# generamos el distplot
sns.distplot(normal_sample_2)
plt.title("histograma del vector 'normal_sample_2' ")
plt.xlabel("valores de la variable aleatoria muestreada")
plt.ylabel("densidad de cada valor muestreado")
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_30316\4236713047.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normal_sample_2)

# %% [markdown]
# Podriamos realizar en un mismo distplot la visualizacion de la densidad de los 2 vectores en simultáneo

# %%
# generamos el distplot, en una misma celda de codigo uno debajo del otro
# plt.show() imprime toda visualizacion que se haya acumulado en esa celda de codigo 
sns.distplot(normal_sample,label = "normal_sample", color = 'green')
sns.distplot(normal_sample_2, label = "normal_sample2", color = 'red')
plt.title("histograma de los dos vectores generados ")
plt.xlabel("valores de la variable aleatoria muestreada")
plt.ylabel("densidad de cada valor muestreado")
plt.legend()
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_30316\330375641.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normal_sample,label = "normal_sample", color = 'green')
# C:\Users\schas\AppData\Local\Temp\ipykernel_30316\330375641.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normal_sample_2, label = "normal_sample2", color = 'red')

# %% [markdown]
# **Scatter plot**
# Si consideramos ambos vectores como coordenadas y cada posicion una muestra (un punto) entonces tenemos 1000 muestras cada una caracterizada por 2 valores (o dimensiones). Dicho esto, podemos entonces visualizar las 1000 muestras caracterizadas por los 2 vectores provenientes cada uno de una distribucion normal con distintos parametros. El scatter plot visualiza nubes de puntos. Seaborn tiene una función para realizar scatter plots.

# %%
# utilizamos cada vector como una dimension, uno para el eje x y otro para el eje y.
sns.scatterplot(x= normal_sample, y= normal_sample_2)
plt.title("Ejemplo de scatterplot con seaborn")
plt.xlabel("valores de normal_sample")
plt.ylabel("valores de normal_sample_2")
plt.show()

# %% [markdown]
# Matplotlib es otra libreria que tambien tiene funciones similares, como scatter plot

# %%
# con el comando plt.scatter() ingresamos los 2 vectores para visualizar las 1000 muestras.
# el parametro "alpha" hace traslucidas las muestras que se solapan una encima de otra.
plt.scatter(normal_sample, normal_sample_2, alpha = 0.3)
plt.title("Ejemplo de scatterplot con matplotlib")
plt.xlabel("valores de normal_sample")
plt.ylabel("valores de normal_sample_2")
plt.show()

# %% [markdown]
# # Librería Pandas: Gestion de datos estructurados (tablas)
# Pandas es una importante libreria de python para manipular datos que esten en un formato de tablas (.csv, .txt, .xls). Con Pandas podremos importar datos obtenidos en los formatos mencionados, por ejemplo el portal de datos abiertos de la Ciudad de Buenos Aires. Puntualmente trabajaremos con los datos de Arbolado Publico Lineal del año 2011 obtenidos del siguiente enlace https://data.buenosaires.gob.ar/dataset/arbolado-publico-lineal.
# Una vez que descargues el dataset de arbolado 2011 guardalo en alguna carpeta de tu computadora y con click derecho "propiedades" fijate cual es la ruta de carpetas donde esta alojado el archivo .csv que descargaste.

# %%
# importamos la libreria pandas
import pandas as pd

# %% [markdown]
# El comando de pandas "pd.read_csv" permite importar archivos .csv alojados en la computadora  a jupyter. El archivo sera importado como una tabla con renglones (rows) y columnas (columns). A las tablas generadas desde Pandas las llamamos "DataFrame". Ver que el parametro que solicita el comando "pd.read_csv()" es la ruta de la carpeta donde esta alojado el archivo (la ruta incluye el nombre del archivo). Eso quiere decir que una vez que descarguen el archivo, lo guardaran en alguna carpeta que creas conveniente y luego obtendrás la ruta.
#
# **Aclaración usuarios windows:** en algunos casos de usuarios con windows, muchas veces se genera un error y es necesario agregar la letra "r" antes de la ruta (algo asi como pd.read_csv(r'Ruta donde el CSV esta guardado\nombre.csv')). Para mas información ver como importar archivos .csv en windows desde este blogpost https://datatofish.com/import-csv-file-python-using-pandas/

# %%
pwd
# Out:
# 'c:\\Users\\schas\\OneDrive - AlixPartners\\Santiago Chas\\clusterai\\ClusterAI_2026\\clase_0'

# %%
# importamos el archivo "arbolado2011.csv" y lo guardamos en la variable "arbolado".
arbolado = pd.read_csv('./arbolado-publico-lineal-2011.csv', header = 0, index_col = 'id_arbol')

# %%
# importamos el archivo "arbolado2011.csv" y lo guardamos en la variable "arbolado".
#arbolado = pd.read_csv(r"C:\Users\kevin.dobzewicz\Desktop\Ciencia-de-Datos-UTN-FRBA-main\clase00\arbolado-publico-lineal-2011.csv", header = 0, index_col = 'id_arbol')

# %% [markdown]
# #### Parte de las visualizaciones que observes en las próximas lineas fueron implementadas por los estudiantes de Ingeniería Industrial Agustin Tettamanti, Daniela Morini y Alejandra Zuñiga. Podrás encontrar el trabajo completo de ellos en https://github.com/atettamanti/TP-grupo-0

# %%
# averiguamos que tipo de variable es matrimonios: un DataFrame de Pandas.
type(arbolado)
# Out:
# pandas.core.frame.DataFrame

# %%
# Con np.shape() nos fijamos que dimension tiene el archivo (renglones, columnas)
np.shape(arbolado)
# Out:
# (372699, 19)

# %% [markdown]
# Al DataFrame "matrimonios" podemos solicitarle información como visualizar los primeros renglones agregando al nombre del dataframe el comando ".head()". Por default aparecen 5 renglones. Observaremos que además del contenido de cada registro de matrimonio, el dataframe se caracteriza por tener un indice (el nombre de cada renglon) y columnas (cada columna tiene un nombre).

# %%
# con .head() visualizamos los primeros 5 renglones del dataframe.
arbolado.tail(2)
# Out:
#                 long        lat tipo_sitio  altura_tot  diametro  inclinacio  \
# id_arbol
# 938000242 -58.493116 -34.623887      Árbol          10        58           0
# 938000243 -58.493086 -34.624042      Árbol           3         5           0
#
#            id_especie nombre_fam     nombre_gen            nombre_cie  \
# id_arbol
# 938000242           3  Meliáceas          Melia       Melia azeradach
# 938000243           8  Litráceas  Lagerstroemia  Lagerstroemia indica
#
#                            nombre_com                     tipo_folla   origen  \
# id_arbol
# 938000242                     Paraíso  Árbol Latifoliado Caducifolio  Exótico
# 938000243  Crespón (Àrbol de Júpiter)  Árbol Latifoliado Caducifolio  Exótico
#
#           codigo_man    barrio  comuna               calle  chapa1  chapa2
# id_arbol
# 938000242    79-005A  FLORESTA      10            Sanabria       0       0
# 938000243    79-005A  FLORESTA      10  Diaz, Cesar, Gral.       0       0

# %%
# podemos tambien acceder al listado de columnas 
arbolado.columns
# Out:
# Index(['long', 'lat', 'tipo_sitio', 'altura_tot', 'diametro', 'inclinacio',
#        'id_especie', 'nombre_fam', 'nombre_gen', 'nombre_cie', 'nombre_com',
#        'tipo_folla', 'origen', 'codigo_man', 'barrio', 'comuna', 'calle',
#        'chapa1', 'chapa2'],
#       dtype='object')

# %%
# tambien podemos acceder al vector de indices
arbolado.index
# Out:
# Index([     2430,      2431,      2432,      2433,      2434,      2435,
#             2436,      2437,      2438,      2440,
#        ...
#        938000234, 938000235, 938000236, 938000237, 938000238, 938000239,
#        938000240, 938000241, 938000242, 938000243],
#       dtype='int64', name='id_arbol', length=372699)

# %% [markdown]
# el vector de indices es impreso en pantalla como un elemento "RangeIndex" con comienzo en 0 y fin en 11732, que equivale a la cantidad de renglones. Python en algunos casos en vez de imprimir literalmente un vector que vaya de 0 a 11732 con incrementos de +1, utiliza el formato "range" indicando el inicio, fin y el "paso" entre cada registro.

# %% [markdown]
# #### Limpiar y pre-procesar los datos

# %%
# Vamos a ver cuantos elementos de cada columna tienen valores nulos (NaNs)
arbolado.isnull().sum()
# Out:
# long          0
# lat           0
# tipo_sitio    0
# altura_tot    0
# diametro      0
# inclinacio    0
# id_especie    0
# nombre_fam    0
# nombre_gen    0
# nombre_cie    0
# nombre_com    5
# tipo_folla    0
# origen        0
# codigo_man    0
# barrio        0
# comuna        0
# calle         0
# chapa1        0
# chapa2        0
# dtype: int64

# %%
# Con el comando .dropna() eliminamos todas las filas que tengan algún valor nulo 
arboles = arbolado.dropna()

# %%
# con .shape podemos ver el tamaño del dataframe por filas y columnas
arboles.shape
# Out:
# (372694, 19)

# %%
type(arbolado.isnull().sum().max())
# Out:
# numpy.int64

# %%
# imprimimos la cantidad de filas eliminadas
print("La cantidad de nulos eliminados de los datos es: "+ str(arbolado.isnull().sum().max()))
# Out:
# La cantidad de nulos eliminados de los datos es: 5

# %% [markdown]
# ### Visualizar dataframes con Seaborn y Matplotlib

# %%
plt.figure (figsize=(15,6))
ax = sns.countplot(x="barrio", data=arboles)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.title("Cantidad de árboles por barrio")
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_30316\3671450575.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
plt.figure (figsize=(15,6))
ax = sns.countplot(x="nombre_com", data=arboles)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.title("Cantidad de árboles por barrio")
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_30316\3136364314.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
print("El TOP5 de barrios con mayor cantidad de árboles es:                                                                           " 
      + str(arboles.barrio.value_counts(ascending=False).head()))
# Out:
# El TOP5 de barrios con mayor cantidad de árboles es:                                                                           barrio
# PALERMO         22483
# MATADEROS       18289
# VILLA DEVOTO    17537
# CABALLITO       15660
# FLORES          15278
# Name: count, dtype: int64

# %%
arboles.barrio.value_counts(ascending=False).head()
# Out:
# barrio
# PALERMO         22483
# MATADEROS       18289
# VILLA DEVOTO    17537
# CABALLITO       15660
# FLORES          15278
# Name: count, dtype: int64

# %%
arboles.barrio.value_counts(ascending=False).head()
# Out:
# barrio
# PALERMO         22483
# MATADEROS       18289
# VILLA DEVOTO    17537
# CABALLITO       15660
# FLORES          15278
# Name: count, dtype: int64

# %%
# imprimimos todos los valores posibles que pueden haber en la columna "tipo_folla"
print("tipo_folla")
print(arboles.tipo_folla.unique())
# Out:
# tipo_folla
# ['Árbol Latifoliado Caducifolio' 'Árbol Latifoliado Perenne'
#  'No Determinado' 'Arbusto Perenne' 'Árbol Conífero Perenne' 'Palmera'
#  'Arbusto o Herbacea' 'Arbusto Caducifolio' 'Árbol Conífero Caducifolio'
#  'Miscelaneo']

# %%
# Grafico de barras para contar cuantos arboles hay por tipo de folla
plt.figure(figsize=(15,6))
ax = sns.countplot(x="tipo_folla", data=arboles)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.title("Cantidad de árboles por tipo de hoja")
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_30316\2220465762.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
print("El TOP3 de cantidad de arboles por tipo de hoja son:                                                                           " 
      + str(arboles.tipo_folla.value_counts(ascending=False).head(3)))
# Out:
# El TOP3 de cantidad de arboles por tipo de hoja son:                                                                           tipo_folla
# Árbol Latifoliado Caducifolio    296880
# Árbol Latifoliado Perenne         56061
# No Determinado                    12761
# Name: count, dtype: int64

# %%
print("El TOP5 de cantidad de arboles por tipo de familia es:                                                                           " 
      + str(arboles.nombre_fam.value_counts(ascending=False).head()))
# Out:
# El TOP5 de cantidad de arboles por tipo de familia es:                                                                           nombre_fam
# Oleáceas       175247
# Platanaceae     35152
# Moráceas        27064
# Meliáceas       24681
# Leguminosas     22355
# Name: count, dtype: int64

# %%
# hacemos un grafico de barras para saber cuantos arboles hay por cada valor de la columna "origen"
plt.figure (figsize=(8,6))
ax = sns.countplot(x="origen", data=arboles)
plt.title("Cantidad de árboles por origen")
plt.show()

# %%
print("Cantidad de arboles por origen:"+str(arboles.origen.value_counts(ascending=False).head(3)))
# Out:
# Cantidad de arboles por origen:origen
# Exótico             334503
# Nativo/Autóctono     30410
# No Determinado        7781
# Name: count, dtype: int64

# %% [markdown]
# #### Vamos a visualizar la distribución de valores que tiene la variable diametro en todo el dataset

# %%
plt.figure(figsize=(10,3))
sns.distplot(arboles.diametro, color="Green")
plt.xlabel("Diametro")
plt.ylabel("Frecuency")
plt.title('Distribucion del diametro',size = 20)
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_30316\3001448137.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(arboles.diametro, color="Green")

# %% [markdown]
# #### Realizaremos un boxplot para entender la distribución en quantiles de la altura por barrio

# %%
g = sns.catplot(x="barrio",y="altura_tot",data=arboles, kind="box", height = 5 ,aspect=3,palette = "muted")
g.despine(left=False) # Para quitar los el eje Y del plot
g.set_xticklabels(rotation=90)

plt.xlabel("Familia")
plt.ylabel("Altura")
plt.title('Boxplot de Altura VS Familia',size = 12)
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_30316\707583045.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(x="barrio",y="altura_tot",data=arboles, kind="box", height = 5 ,aspect=3,palette = "muted")

# %% [markdown]
# #### El pairplot ayuda a entender como co-varian cada par de variables y así poder visualizar si existe o no algún tipo de correlación
# En este caso solo lo realizaremos para las variables
# - Diametro
# - Altura
# - Inclinación

# %%
sns.pairplot(arboles[["diametro", "altura_tot", "inclinacio"]])
plt.show()

# %% [markdown]
# #### Ahora generamos una matriz de correlación entre pares de variables

# %%
#arboles[["diametro", "altura_tot", "inclinacio"]]

# %%
#Se observa una correlacion lineal bastante fuerte entre Altura y Diámetro
corrmat = arboles[["diametro", "altura_tot", "inclinacio"]].corr()
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
corrmat
# Out:
#             diametro  altura_tot  inclinacio
# diametro    1.000000    0.653080    0.057734
# altura_tot  0.653080    1.000000    0.101717
# inclinacio  0.057734    0.101717    1.000000

# %%
type(corrmat)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Funciones en python
# Supongamos que queremos utilizar muchas veces un mismo segmento de codigo. En vez de repetirlo multiples veces, podemos crear funciones de python. Cada vez que necesitamos realizar dicha acción llamamos a la función. Vamos a crear una función para imprimir el valor de una posición dentro de un pandas dataframe.

# %%
# Las funciones deben declararse con "def + nombre de la funcion" y entre (input)
def imprimir_dato(dato):
    
    return print("El dato en cuestion es " + str(dato))

# %%
arboles.nombre_fam.values[2]
# Out:
# 'Oleáceas'

# %% [markdown]
# Podriamos usar la función definida para situaciones puntuales, por ejemplo para el tercer registro del dataframe "arboles". Recordemos que si hablamos del tercer elemento entonces su indice será el 2, ya que en Python los índices comienzan en 0.

# %%
imprimir_dato(arboles.nombre_fam.values[2])
# Out:
# El dato en cuestion es Oleáceas

# %% [markdown]
# # For loops
# Muchas veces vamos a necesitar iterar sobre una matriz o vector para realizar alguna operación particular. Esto se puede lograr mediante los loops "for". El mismo debe definir un elemento iterador que cambiará de valor en cada paso del loop. En el ejemplo el iterador será la variable "i" y su rango de iteración será desde 0 a 4. El rango va de 0 a 5 indicando el valor de comienzo y el valor final-1 (así es la sintaxis de python).

# %%
for i in range(0,15):
    imprimir_dato(arboles.nombre_fam.values[i])
# Out:
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Aceráceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Rosáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Moráceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas

# %%
arboles.nombre_fam.values[0:15]
# Out:
# array(['Oleáceas', 'Oleáceas', 'Oleáceas', 'Aceráceas', 'Oleáceas',
#        'Rosáceas', 'Oleáceas', 'Oleáceas', 'Oleáceas', 'Oleáceas',
#        'Moráceas', 'Oleáceas', 'Oleáceas', 'Oleáceas', 'Oleáceas'],
#       dtype=object)

# %% [markdown]
# De esta manera generamos un loop de 15 iteraciones que imprime el valor de la comuna en la posicion "i" del vector "comunas"

# %% [markdown]
# **Lo lograste!**
# Si llegaste a este punto quiere decir que pudiste ejecutar:
# - Abrir un Jupyter notebook exitosamente.
# - Operaciones básicas en Python como print o suma.
# - Utilizar Numpy para crear arrays y realizar operaciones con ellos.
# - Utilizar Numpy para crear vectores provenientes de distribuciones normales de probabilidad.
# - Visualización con matplotlib y seaborn para hacer Scatter, Distplot, Countplot.
# - Importar archivos .csv con Pandas
# - Filtrar por columnas con Pandas
# - Crear funciones de Python
# - Generar for loops

# %% [markdown]
# **Como seguir:** Queda mucho por hacer aunque lograr ejecutar este notebook fue un gran logro. Te invitamos a que trates de comprender el paso a paso, amigarte con la sintaxis y modificar algunas variables clave en cada ejercicio para obtener otros resultados.
