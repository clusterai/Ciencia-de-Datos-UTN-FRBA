# %% [markdown]
# # Primeros pasos en python

# %% [markdown]
# **ClusterAI 2021
# Ciencia de Datos - Ingenieria Industrial UTN BA <br>
# Curso I5521 <br>
# Docente: Kevin Dobzewicz  <br>
# Autor: Martin Palazzo <br>
# Clase00: Primeros pasos Python**  <br>

# %% [markdown]
# ### Instrucciones y pasos a seguir para poder realizar la primer inmersión en python:

# %% [markdown]
# En este jupyter notebook se abordan las asignaciones para los primeros pasos en python. Se observarán las funciones básicas, familiarización con el sintaxis y práctica necesaria para poder continuar con las asignaciones de futuras clases. Aprender esta herramienta será util para desarrollar distintas aplicaciones de data science y analisis de datos. Te sugerimos fervientemente que sigas el objetivo de este código al ejecutarlo por completo (o hasta donde llegues).

# %% [markdown]
# **Objetivo de este codigo:** lo importante es poder ejecutarlo, tratar de leer el codigo e interpretar la sintaxis. Observar detalladamente el paso a paso para ganar nociones de como se escribe codigo en python. Fijense que dejamos muchas notas para que puedas seguir todas las acciones realizadas :). Asuman esta etapa como "aprender un idioma nuevo". Inicialmente sera un poco confuso, aunque a medida que pase el tiempo lo adoptaran y se sentiran mas comodos.

# %% [markdown]
# **Como ejecutar este archivo:** La manera en que se ejecuta cada celda de Jupyter es mediante "Shift + Enter" o con el boton de "play" que se encuentra en la barra superior. Una vez ejecutado todo el codigo, sientanse libres de modificar algunas variables a su gusto para ir obteniendo distintos resultados. Por ejemplo, crear matrices o vectores de distintas dimensiones, etc.

# %% [markdown]
# # Primeros pasos
# **Imprimir texto en pantalla (hola mundo)**

# %%
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# **Operaciones básicas con enteros**
# Antes de utilizar cualquier librería, python ya permite dentro de su sintaxis realizar algunas operaciones matematias con integers (enteros) o floats (reales).

# %%
(5+3)*10
# Out:
# 80

# %% [markdown]
# A la operación anterior podría guardarla en una variable (llamada "cuenta"), para que quede en memoria y asi poder acceder a su contenido en el futuro.

# %%
# guardamos la operacion en la variable "cuenta"
cuenta = (5+3)*10

# %%
# accedemos al interior de la variable "cuenta" para asegurarnos que se guardo bien los datos del resultado
cuenta
# Out:
# 80

# %%
# el comando "type" nos permite poder saber que tipo de formato de dato esta guardado en la variable en cuestion
type(cuenta)
# Out:
# int

# %% [markdown]
# ## Librería Numpy

# %% [markdown]
# **Importar librerias:**
# Python posee ya muchas librerías con funciones específicas según la tarea que querramos realizar. Existen librerías de cálculo, de visulización, de estadística, procesamiento de señales, de algebra lineal y de redes neuronales artificiales (entre muchas mas). Nuestro primer paso será importar **Numpy**, una importante librería que nos permitirá realizar operaciones numéricas con matrices, vectores y escalares.

# %%
# importamos la librería Numpy
import numpy as np

# %% [markdown]
# **Primeras operaciones con Numpy**:
# Con "np. + comando" de numpy podremos realizar muchas operaciones. Como crear una matriz de 2x2 de ceros.

# %%
# creamos la matriz de 2x2 llena de ceros con el comando np.zeros()
nula = np.zeros((2,2))

# %%
# La visualizamos en pantalla
nula
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
# con type nos fijamos que tipo de variable es "nula"
# python permite muchos tipos de variables, en este caso es un numpy array
type(nula)
# Out:
# numpy.ndarray

# %%
# con np.shape() podremos saber las dimensiones de la variable en cuestion
np.shape(nula)
# Out:
# (2, 2)

# %%
np.shape(cuenta)
# Out:
# ()

# %% [markdown]
# Las posiciones en python comienzan en 0. Entonces si tenemos un elemento de 4 posiciones, la primera sera la posicion 0 y la ultima posicion sera la 3. Cuando tenemos matrices (arrays)

# %%
# si quisieramos acceder al elemento 0,0 de nula 
nula[0,0]
# Out:
# np.float64(0.0)

# %% [markdown]
# Una vez declarada en python, podemos modificar alguno de los elementos de la matriz (numpy array) nula.

# %%
# por ejemplo el de la posicion 1,0
nula[1,0] = 4

# y tambien modificamos la posicion 0,1
nula[0,1] = 10

# %%
# imprimimos la matriz nula en pantalla para observar la modificacion realizada
nula
# Out:
# array([[ 0., 10.],
#        [ 4.,  0.]])

# %% [markdown]
# podriamos realizar operaciones logicas y obtener resultados "booleanos" (True or False). Por ejemplo, preguntamos que elementos son mayores a cero.

# %%
nula_mayor_cero = nula > 0

# %%
nula_mayor_cero
# Out:
# array([[False,  True],
#        [ True, False]])

# %% [markdown]
# Calculamos raiz cuadrada de todos los elementos de la matriz nula con el comando np.sqrt(). SQRT significa square root en ingles.

# %%
# podriamos calcular la raiz cuadrada de todos los elementos de nula con "np.sqrt()"
raiz_cuad = np.sqrt(nula)
raiz_cuad
# Out:
# array([[0.        , 3.16227766],
#        [2.        , 0.        ]])

# %% [markdown]
# con el comando de python de doble * se realiza el cuadrado del elemento en cuestion

# %%
# observamos que si a raiz_cuad la afectamos por el cuadrado obtenemos nuevamente nula
raiz_cuad**2
# Out:
# array([[ 0., 10.],
#        [ 4.,  0.]])

# %%
type(raiz_cuad)
# Out:
# numpy.ndarray

# %% [markdown]
# Numpy tambien nos permite crear matrices de la dimension que querramos con numeros aleatorios mediante el comando "np.random.rand()".

# %%
# creamos un array de 3x3 con todos sus elementos completados nros aleatorios de una distribución uniforme 
array_uniform = np.random.rand(3,3)
array_uniform
# Out:
# array([[0.81536349, 0.70191032, 0.08494451],
#        [0.61687866, 0.9705727 , 0.08089385],
#        [0.08917362, 0.83774101, 0.21795673]])

# %% [markdown]
# Podemos tambien crear vectores, solamente especificando una sola dimension.

# %%
# generamos un vector de 10 posiciones completados desde nros. aleatorios de una dist. uniforme
vector_uniform = np.random.rand(10)
vector_uniform
# Out:
# array([0.81700485, 0.60911851, 0.96921844, 0.06206919, 0.73629621,
#        0.73252935, 0.67961197, 0.20281018, 0.46126193, 0.42094267])

# %%
np.shape(vector_uniform)
# Out:
# (10,)

# %%
type(vector_uniform)
# Out:
# numpy.ndarray

# %% [markdown]
# Trasponer un numpy array con ".T" al final

# %%
# vamos a transponer la matriz array_uniform
array_uniform_t = array_uniform.T
array_uniform_t
# Out:
# array([[0.81536349, 0.61687866, 0.08917362],
#        [0.70191032, 0.9705727 , 0.83774101],
#        [0.08494451, 0.08089385, 0.21795673]])

# %% [markdown]
# Calcular la inversa de una matriz (en formato numpy array) con el comando np.linalg.inv()

# %%
# podemos tambien calcularle la inversa a la matriz array_uniform
array_uniform_inv = np.linalg.inv(array_uniform)
array_uniform_inv
# Out:
# array([[ 2.23030228, -1.26930169, -0.39812141],
#        [-1.97379578,  2.63927926, -0.21030934],
#        [ 6.67401077, -9.62504932,  5.55929931]])

# %% [markdown]
# Calcular el producto de dos matrices con np.dot

# %%
# podemos calcular el producto punto (dot product) entre array_uniform y array_uniform_inv
array_uniform_dot = np.dot(array_uniform, array_uniform_inv)
array_uniform_dot
# Out:
# array([[ 1.00000000e+00, -2.00716439e-17, -1.78532026e-17],
#        [ 1.06850999e-16,  1.00000000e+00,  4.60330457e-17],
#        [ 2.40874680e-16, -1.05347407e-16,  1.00000000e+00]])

# %% [markdown]
# Crear una matriz con valores determinados por el usuario

# %%
# tambien podriamos crear una nueva matriz con datos ingresados 
a=np.array([[1  ,-4],[12 , 3]])
a
# Out:
# array([[ 1, -4],
#        [12,  3]])

# %% [markdown]
# ## Distribuciones de probabilidad con numpy

# %% [markdown]
# Generamos un vector cuyas posiciones sean numeros aleatorios provenientes de una distribucion normal con media y desvio standard determinado.

# %%
# declaramos las variables numericas "mu" y "sigma"
mu = 0
sigma = 0.1 
# con las variables declaradas generamos un vector de 1000 posiciones
# cada posicion es un numero aleatorio extraido de una distribucion normal
normal_sample = np.random.normal(mu, sigma, 1000)

# %%
# si quisieramos ver las dimensiones del vector usamos el comando np.shape
np.shape(normal_sample)
# Out:
# (1000,)

# %%
# si quisieramos saber que tipo de variable es "normal_sample" usamos el comando type
type(normal_sample)
# Out:
# numpy.ndarray

# %%
# si quisieramos saber el valor de la posicion 51 del vector "normal_sample"
normal_sample[50]
# Out:
# np.float64(-0.04966143975066367)

# %%
# podemos redondear el valor obtenido en la celda anterior con "np.round()"
# le pedimos 4 decimales
np.round(normal_sample[50],4)
# Out:
# np.float64(-0.0497)

# %%
# imprimimos en pantalla el vector correspondiente
normal_sample
# Out:
# array([ 5.25381530e-03,  1.75263650e-01, -3.08184587e-02,  3.80319317e-02,
#        -4.06774266e-02,  3.10487228e-02,  1.29653948e-01,  2.37746577e-01,
#        -1.02309141e-01, -2.44501292e-02, -7.86594575e-02, -1.00008628e-02,
#         7.29217425e-02, -3.16117614e-02, -5.55834065e-02,  1.12647541e-01,
#        -9.09537654e-02,  3.45813152e-02,  3.57547395e-02,  4.89151279e-03,
#        -1.33700547e-02,  2.33189520e-02, -1.11613779e-01,  1.27742951e-02,
#        -4.13104926e-02, -1.01064138e-01,  1.31957930e-01, -3.92331720e-02,
#        -1.01359284e-01, -1.35575933e-01,  1.42496771e-01, -8.42788708e-02,
#         1.16530623e-01, -1.87161408e-01, -1.50477225e-01,  1.78798910e-01,
#        -1.14423233e-01, -1.70122731e-02,  5.74640388e-02,  1.19639177e-01,
#        -4.84948872e-02, -2.60547589e-02, -1.04072783e-01, -4.95879367e-02,
#        -5.30253538e-02,  4.96256096e-02,  3.66716761e-02,  5.28093961e-02,
#        -4.66380789e-02,  4.95095009e-02, -4.96614398e-02, -1.18029802e-01,
#        -1.34815945e-01,  1.14364087e-01, -1.09279624e-01, -1.68697528e-01,
#         1.16381364e-02, -1.52472925e-01, -1.60560153e-01,  2.28280840e-02,
#        -1.31414895e-02,  2.68881832e-02,  1.02318550e-01, -1.34212852e-01,
#        -1.30103020e-01,  9.19326302e-02,  3.81406797e-02, -1.25555915e-01,
#         1.04756094e-01,  9.88882321e-02,  7.45473919e-02,  4.64066085e-02,
#         1.20733735e-01, -9.64874433e-02,  1.05059574e-01,  6.31526525e-02,
#         1.44735689e-01, -2.15046129e-02,  9.88156772e-02, -8.08653992e-02,
#        -8.89483427e-03,  2.03245064e-01,  6.38268401e-02, -5.92122023e-02,
#        -1.21277559e-02, -1.67199676e-01, -6.29828296e-02, -1.08906941e-01,
#         3.95631102e-02,  2.00555405e-01, -1.92482879e-02,  2.41681605e-01,
#        -1.46483582e-01, -4.14771847e-02,  9.37470304e-04,  2.25281912e-01,
#         3.15649510e-02, -4.46154489e-02,  8.10686707e-02, -4.57160110e-02,
#         3.97345436e-02,  2.43064740e-02,  9.25111395e-02, -1.56892363e-02,
#        -6.19080126e-02, -7.32798427e-02, -4.06696790e-02,  6.54500802e-03,
#        -1.06961348e-01,  3.41010591e-02, -2.88013827e-02,  5.72206769e-02,
#         7.93837135e-02,  9.72668416e-02, -1.92700771e-02,  7.34554152e-02,
#        -6.49312891e-02,  1.36367038e-01, -2.78888826e-02,  1.00464979e-01,
#         1.22403349e-02,  1.99725468e-02,  1.57035370e-01, -1.02088128e-01,
#         4.25818409e-02, -7.39231392e-02, -1.19481686e-01, -2.31835979e-01,
#        -1.94108668e-01,  5.15420517e-02,  1.95333594e-01,  4.06484171e-02,
#        -5.32924828e-02,  4.76597054e-02,  6.87698186e-02,  7.95135360e-02,
#        -6.02656186e-03, -9.67969799e-02, -8.81252134e-02, -1.22092990e-01,
#        -8.11471234e-02, -8.27958109e-03,  6.93696157e-03, -1.07610009e-01,
#         4.00257736e-02,  1.79473178e-01,  1.59665543e-01, -1.33618244e-01,
#        -2.40475686e-02,  2.11701830e-02,  7.24975781e-03,  1.75713901e-01,
#        -4.46697508e-02,  1.78378229e-01, -8.21211743e-03, -6.62969053e-02,
#         7.20988815e-02,  2.43641188e-01, -1.59446695e-01,  2.39868851e-02,
#         1.39001689e-01,  2.68656279e-01,  3.70896860e-02,  2.08417674e-01,
#         1.12174300e-01, -1.14086065e-01, -5.93301039e-02, -5.27619136e-02,
#         1.24490164e-01, -1.15004516e-01,  1.23576535e-01, -1.80395129e-01,
#        -8.76037251e-02, -1.57692980e-01,  2.47795754e-02,  3.00748245e-02,
#        -3.60217439e-02,  2.27004975e-02, -3.13604858e-03, -1.33254274e-02,
#        -4.33615086e-03, -6.14302050e-02,  1.71258938e-01,  1.59898639e-02,
#         8.53150280e-02,  3.28456538e-02, -1.10221188e-01,  2.03071916e-02,
#        -1.91411774e-02,  2.24844783e-01, -3.54319327e-02,  1.22675170e-01,
#        -9.92546138e-02, -1.16198442e-01,  3.67242295e-02, -8.97002203e-02,
#         2.23855239e-01, -9.64254181e-03,  3.27869200e-02, -4.28902176e-02,
#        -1.93337548e-01, -6.93239345e-02, -2.35934752e-02, -1.39850414e-02,
#        -6.82771058e-02, -6.58868860e-02,  6.91370397e-02, -6.45318480e-02,
#        -2.52285564e-02, -5.07639219e-02, -5.05979785e-02, -1.26568947e-02,
#         1.57016146e-02,  9.36150916e-02, -9.17219116e-02, -2.76000828e-01,
#        -2.08140534e-01,  1.13758073e-01,  1.34883698e-01, -2.18997634e-01,
#         1.39462074e-01, -2.55398985e-03,  8.98493809e-02, -5.30488847e-02,
#         5.82351567e-02, -4.48018524e-02,  9.81485433e-02, -1.53967678e-01,
#         7.33777809e-02,  1.35766296e-01,  1.45016949e-01,  1.21171973e-01,
#         3.25732213e-02, -9.25047630e-02,  3.84688812e-02,  1.84309169e-01,
#        -1.19794724e-01,  2.42051207e-01, -8.23214943e-02, -5.22188296e-02,
#        -1.61982058e-02, -6.00649174e-02, -5.21453511e-02,  9.28874427e-02,
#         7.76785560e-02,  1.99110740e-02,  3.03550327e-02,  1.66947812e-01,
#        -1.25338589e-01, -1.10187571e-01,  3.19476400e-02, -5.93721055e-03,
#        -1.39741855e-01, -1.05271426e-01, -2.00495357e-01, -5.84343413e-03,
#         9.46973742e-02, -9.20867922e-02,  4.17678374e-02,  1.04222989e-01,
#         6.95387076e-02, -1.82505471e-01,  5.54942531e-03,  1.16533403e-02,
#        -1.87988055e-02,  4.24977495e-02,  1.39270523e-01, -2.40667671e-02,
#        -4.13839386e-02, -3.09530222e-02,  6.42624951e-02,  5.59980918e-02,
#         2.91427252e-02,  4.99439881e-02, -3.34712276e-02,  7.69768438e-03,
#         6.58846258e-02, -7.84781727e-03, -6.81005010e-02,  7.80646110e-02,
#        -1.67632160e-01, -9.89137111e-02, -1.30606487e-02,  1.77950199e-01,
#         6.62079216e-02, -9.36528925e-02, -5.59158779e-02,  1.02619865e-01,
#         8.80171252e-02, -1.02919550e-02,  1.53578297e-01, -4.26564075e-02,
#         4.78609356e-02, -1.43020995e-01, -6.18437952e-02, -1.46717563e-02,
#         5.09444718e-02, -1.21357682e-01, -9.14325347e-02, -1.25930016e-01,
#        -1.18205713e-01, -4.92054894e-02,  1.48293509e-01,  1.31643903e-01,
#        -1.65952411e-03,  3.53287407e-02, -9.96166720e-03, -2.69524937e-02,
#         4.70640346e-03,  8.31233178e-02, -2.07249462e-02,  1.07324913e-01,
#         1.78062702e-01, -1.01567096e-01, -3.97869307e-02, -1.90547367e-01,
#        -1.26490717e-01,  1.62184374e-01,  9.47293677e-02, -2.31972635e-03,
#         1.21565133e-02,  6.31499886e-03,  2.63863876e-02,  8.27837926e-02,
#         6.77570081e-02, -3.32209518e-02,  5.18252321e-02, -4.78669379e-02,
#         1.15928627e-01,  1.21607391e-01,  2.02043232e-01, -8.00669956e-02,
#        -1.36867634e-01, -3.34257059e-02,  9.16224751e-02,  3.99228147e-03,
#         1.13176193e-01,  5.96538543e-02, -1.31329784e-01, -5.55601279e-02,
#        -1.56129221e-01, -2.31221554e-02,  1.15803662e-01, -3.02719766e-02,
#         1.21167821e-01, -1.86142655e-02, -3.08946470e-01,  9.15929653e-02,
#         4.69214363e-03,  1.53655972e-01,  4.79865557e-02,  3.53950447e-02,
#        -9.97776498e-03, -7.18714906e-02, -5.87549514e-02,  6.95566488e-02,
#         5.72336291e-02,  4.21589484e-02,  3.78939113e-02, -9.63360096e-02,
#        -9.00917077e-02,  1.39502874e-01,  8.10625576e-02, -1.28327579e-03,
#         2.80816907e-02,  4.64467724e-02,  9.58204996e-02, -1.06996942e-01,
#        -2.25810395e-02, -9.40749929e-03, -5.12938523e-03, -1.45926808e-02,
#         1.87887015e-01,  1.00849695e-01,  9.36012257e-02, -1.56106670e-02,
#         2.06158223e-01, -8.78111283e-02, -6.72263940e-02, -8.75932299e-02,
#         3.42926162e-03, -1.59143346e-02,  6.08919149e-02,  2.58407165e-02,
#        -3.40213989e-02, -1.24145666e-01, -1.42516079e-02, -1.19951483e-01,
#        -1.05378348e-01, -9.58678295e-03,  1.87172799e-02, -3.31986871e-02,
#         7.13877891e-02, -1.06050607e-01,  2.03026360e-02,  9.34956363e-03,
#         5.05713370e-02, -4.72298027e-02,  3.36348174e-02,  1.42857046e-01,
#         5.96163566e-02, -2.02242173e-01,  1.70914568e-01,  9.98300387e-02,
#         4.66702647e-02, -3.96565545e-02,  1.18414742e-02, -1.27669380e-01,
#        -4.11678871e-02,  8.41245128e-04, -2.66762033e-02, -5.81281125e-02,
#        -6.21193121e-02, -2.41368470e-02,  6.74029592e-02,  4.62418640e-02,
#        -1.34345003e-01, -7.96153670e-02,  5.04407984e-03, -2.76387054e-02,
#         9.12791606e-02, -9.42259741e-02, -6.07671820e-02, -5.76409997e-02,
#         1.80757289e-01,  1.29822339e-01, -2.41814917e-03,  1.21084281e-01,
#        -5.14372651e-02, -8.45857574e-02,  1.35121250e-01,  1.42559783e-01,
#         6.97558455e-03,  2.84969035e-01,  4.15080515e-02,  1.86828035e-01,
#        -1.17423581e-01,  8.95423741e-02, -9.10736775e-02, -6.95455656e-03,
#        -3.43835489e-02, -2.96568136e-02, -2.49057262e-02,  1.98885186e-02,
#        -1.75311030e-02,  7.06172464e-02,  1.51253222e-02,  4.44541884e-02,
#        -9.23018561e-02,  2.05684791e-02,  1.59999711e-02, -1.06951959e-02,
#        -2.83882212e-02,  1.50413324e-02, -1.76326976e-01,  9.00151010e-02,
#        -1.48030778e-01,  2.18717264e-01, -1.07561180e-01, -4.39678823e-02,
#         2.31627004e-01,  1.00840838e-01, -5.10697684e-03,  1.44908925e-01,
#         9.37073398e-02, -1.08232921e-01, -1.11961540e-01,  2.15947331e-01,
#        -1.96283677e-01, -1.80558449e-01,  2.68248978e-03,  7.71328955e-02,
#        -1.94222121e-01, -5.32495180e-02, -1.00615468e-01,  1.68972974e-01,
#        -1.57689632e-02,  6.19689624e-02, -5.76404909e-02,  1.14209325e-01,
#        -3.93296644e-02, -3.72022881e-02, -8.71166899e-02, -2.20022180e-02,
#         8.58417466e-02,  1.46002829e-01,  2.01113477e-01, -4.15395534e-02,
#         8.90178042e-02, -5.45331073e-02, -1.96600454e-02,  2.27599956e-02,
#        -6.22302636e-02, -4.88509768e-02,  8.84236951e-02, -9.80874959e-02,
#        -1.02610539e-01, -1.17945756e-01, -6.68239225e-03, -1.08550475e-01,
#        -6.42600877e-02,  7.60274799e-02,  1.01595566e-01, -3.18288799e-02,
#        -4.77187991e-02,  2.88222112e-02, -6.11351874e-02,  3.94152487e-02,
#        -3.43040639e-02, -1.91660382e-01,  3.09864693e-02,  7.43976957e-02,
#        -8.63493189e-02,  1.86890831e-01, -5.67258413e-02,  3.01420604e-02,
#        -4.69166787e-02, -4.88973811e-02, -3.50922448e-02, -8.64753035e-02,
#        -6.86789890e-02, -9.27997521e-02, -6.60691514e-02, -3.02860104e-02,
#         6.90230526e-03, -6.37627520e-02,  2.75627027e-02,  1.57029155e-02,
#        -7.98894175e-03, -9.05853764e-02,  2.04049837e-02,  4.89969542e-02,
#        -1.62778476e-02, -3.69516783e-02,  7.24501760e-02,  2.23747762e-01,
#        -1.36442715e-01,  6.83189004e-02, -3.34345958e-02, -1.23123291e-01,
#        -1.44431360e-01, -1.66238925e-01,  1.06295687e-01,  8.55369840e-02,
#         2.10014763e-01,  1.90238191e-01, -1.01856086e-01,  9.70118208e-03,
#        -7.13269223e-02,  3.61040339e-02, -1.94189497e-03, -6.27817105e-02,
#         3.23330850e-02, -6.82521017e-02,  5.97561827e-02,  3.26464389e-02,
#         4.45946882e-03,  1.04145944e-01,  7.18000346e-02, -4.41159096e-02,
#        -3.13817822e-02,  1.70209205e-01,  3.29005788e-02,  8.19779530e-02,
#         1.31279300e-01, -1.08880445e-01, -7.40982394e-02, -8.87452768e-02,
#         2.05286880e-01,  9.74657254e-03,  7.60094011e-02,  3.09567661e-02,
#        -2.75131847e-02, -1.28037117e-01, -7.70147530e-02, -6.53290578e-02,
#         1.12870159e-01,  9.40663073e-02, -3.10826373e-02, -6.00193622e-02,
#        -1.66422007e-03, -1.06519315e-01,  4.63075092e-02, -8.06216446e-02,
#         2.71455291e-01,  8.47706180e-02, -3.55921051e-02, -7.29033896e-02,
#         2.72205353e-01, -5.91779075e-02, -2.87718015e-02,  8.08673627e-03,
#        -2.68727114e-02,  1.03195238e-01, -1.65494382e-01, -4.71992976e-02,
#         5.19494785e-02,  6.62018155e-02,  1.39275643e-01, -5.06070251e-02,
#         1.66947048e-02,  1.25101106e-02,  1.00922353e-01,  7.99512033e-03,
#        -3.02535520e-02,  1.80997927e-01,  1.69424725e-02, -1.90706210e-02,
#         5.07364690e-02,  1.83174763e-01, -5.72308297e-02,  1.05931360e-02,
#        -4.75504143e-02, -1.08177416e-02,  1.23968765e-01,  8.74230701e-02,
#         6.60285976e-02, -2.10490024e-01,  2.61291429e-02, -1.03036095e-01,
#         2.68543161e-02, -9.78391339e-02,  6.67419173e-03, -1.12106741e-01,
#        -1.06684710e-01, -6.09160659e-03,  9.02278440e-02, -5.01261888e-04,
#        -1.87177107e-02,  9.27657307e-02,  4.56986588e-03,  8.18990534e-02,
#        -5.29965146e-02, -1.21050446e-01, -1.45242419e-01,  6.93449432e-03,
#        -3.20922818e-02, -4.03749973e-02, -1.08498924e-01,  9.20291425e-02,
#        -1.03404243e-01,  3.51148109e-02,  6.40235162e-02, -2.98459310e-02,
#         7.85958949e-02, -8.02843007e-02,  4.10148639e-02,  1.24117265e-01,
#         3.88575563e-02, -1.95387712e-01, -2.21930586e-02,  2.00992629e-02,
#        -1.30854262e-02, -8.40807712e-02,  4.28177233e-02, -4.20534988e-02,
#        -2.84920685e-02,  1.27782188e-02,  3.83422155e-02,  5.74548943e-02,
#         6.16451258e-03, -2.77035300e-02, -2.99639073e-03, -4.46941552e-02,
#        -7.47738420e-02, -3.40711891e-02,  1.52182360e-02,  1.16382887e-01,
#         1.85874088e-01, -1.30639519e-01, -1.39929899e-01, -4.90082845e-02,
#        -1.03749935e-01, -1.04580025e-01, -2.27007066e-02, -6.93867631e-02,
#        -3.50769774e-02, -6.36245653e-02, -1.24038447e-01, -4.82613171e-02,
#         2.83901991e-02, -1.97186670e-02, -6.45751681e-02, -4.98058615e-02,
#         6.17500902e-04, -6.01991311e-02, -2.37883153e-02, -7.77931343e-02,
#         1.29701885e-02, -9.88581210e-02, -6.45903801e-02,  2.28403400e-01,
#        -6.11072788e-02, -1.50084200e-01,  3.58017007e-02, -4.99861391e-02,
#         9.64414559e-02, -6.48627104e-02,  1.99392452e-02,  4.54717986e-02,
#         1.28846815e-01,  1.53410735e-01, -3.67796762e-03, -2.04443480e-01,
#        -1.32307175e-02, -1.20452189e-01,  1.68372322e-01, -5.39966303e-02,
#         7.72935574e-03,  5.38472152e-02,  7.15271438e-02, -2.17663954e-02,
#         8.16092355e-02, -1.45261542e-01,  1.42360008e-01, -2.41769650e-02,
#         1.09002975e-01,  8.29247651e-02, -7.76454578e-03,  7.97693825e-02,
#        -4.17930888e-02, -3.41461586e-02, -6.47153886e-02, -9.43557104e-02,
#        -7.00169418e-02,  3.37872485e-02, -7.74617811e-03, -1.03251762e-01,
#         1.00330633e-01, -1.41388203e-01,  2.58399382e-02,  7.80445147e-02,
#        -1.43140274e-01,  7.80909554e-02,  1.68552053e-01, -4.09829363e-02,
#         7.03996062e-02,  8.04109446e-02, -2.54381843e-02,  2.32910193e-01,
#        -3.73441889e-02, -9.38497280e-03,  3.66680149e-02,  7.27625921e-03,
#         2.04471122e-01,  8.31504948e-02,  9.98946061e-02,  8.50824068e-02,
#        -6.75690740e-02, -5.15255816e-02, -5.58769942e-02,  3.59927885e-02,
#         3.44045918e-02,  3.67812627e-02, -6.53186317e-03, -3.11310811e-02,
#         3.10731513e-02, -3.81542642e-02, -2.30192469e-01,  2.13642490e-01,
#         1.00354685e-01, -7.48461596e-02,  1.63229536e-01,  1.08104644e-01,
#        -2.00369963e-01, -1.28872301e-01,  7.08423216e-02, -5.32678013e-02,
#        -1.89044599e-01,  5.74844126e-02,  4.81601008e-02,  7.05669305e-02,
#         1.45331831e-01,  1.15177623e-01, -1.14405426e-02, -7.09856961e-02,
#        -5.46423465e-02, -6.68129945e-02, -4.90363222e-02,  1.14119685e-01,
#         4.57219483e-02,  2.52387667e-02,  2.11414319e-01, -4.86451010e-02,
#        -7.91196947e-02, -2.88517563e-02, -1.27149564e-01, -4.64295605e-02,
#        -1.53740269e-02, -8.29113795e-02, -2.51284023e-02, -3.42239125e-02,
#        -2.20288121e-02, -2.14360608e-02, -9.81504340e-03, -4.57928237e-02,
#         5.73073789e-02,  6.91386671e-02,  1.23903174e-01,  1.25160119e-01,
#        -1.61915099e-02, -2.08825473e-02,  1.79070594e-01, -2.31252293e-01,
#        -7.39427060e-02,  7.74128613e-02, -8.00061761e-02,  5.51692242e-02,
#        -1.06353262e-01,  6.21941702e-02, -9.40609269e-02,  6.41963099e-03,
#         7.12380993e-02,  4.35897381e-02, -4.92146170e-03, -9.89849129e-02,
#         1.02391281e-01, -6.02202333e-02, -7.74632531e-02, -2.29014193e-02,
#        -4.53834599e-02, -5.46852701e-02, -5.19022607e-02, -9.12237987e-02,
#         7.68169242e-02, -4.90527654e-02, -1.22208761e-02,  9.28752475e-02,
#        -6.92062358e-02,  1.28818608e-01, -1.04586439e-02, -1.12245327e-01,
#        -1.39138452e-01,  9.28084688e-02, -2.31090495e-02,  2.07918763e-02,
#         9.94223852e-02, -2.15063986e-02,  8.61785685e-02,  2.22626398e-02,
#         1.04659851e-01,  8.49541344e-02, -1.91096789e-01, -1.48853030e-01,
#        -1.36677664e-01, -4.81825377e-02,  9.08056989e-03, -1.32426199e-01,
#         5.13195163e-02, -1.56756551e-01, -1.37520564e-01,  6.00608052e-02,
#         5.82140951e-02, -2.31528256e-02,  2.96098666e-02,  1.15893118e-01,
#        -2.14010473e-03,  9.89542666e-02,  1.20233796e-01, -9.21361910e-02,
#        -1.67254158e-03,  4.35920253e-02,  2.54906790e-02,  5.72602792e-02,
#         8.07044983e-02, -5.36216835e-02, -1.36923464e-01,  1.44358415e-01,
#         1.92739832e-02, -1.34161435e-01, -3.89732159e-02, -2.03377201e-02,
#        -5.36538968e-02, -5.36027277e-02,  1.38372221e-01,  1.40247167e-02,
#         1.70692840e-01,  1.21341213e-01,  9.15459805e-02,  1.74905827e-01,
#         5.50124700e-02, -3.70995214e-02, -1.87900709e-02, -1.18106633e-01,
#         8.55100197e-02,  9.94327348e-03,  1.02901446e-01,  3.24367324e-02,
#         4.98534857e-03,  7.70251806e-02,  4.66618037e-05,  1.56301490e-01,
#         8.29811582e-02,  1.21700762e-01,  2.92429016e-01,  1.13135796e-02,
#        -1.56042902e-01,  9.74791858e-02,  1.25481173e-01, -1.17673153e-01,
#        -5.29879375e-02, -5.18627798e-02,  2.55775791e-02,  1.61492525e-01,
#        -5.41581340e-02, -2.90276295e-02,  4.57585788e-03,  2.15923480e-02,
#        -1.07401295e-01, -4.63207865e-03,  1.26333996e-02, -5.18842551e-02,
#         9.58721364e-03,  2.67788071e-02,  5.19420445e-02, -8.13501584e-02,
#        -1.68237778e-01, -7.14814554e-02, -1.04200136e-01, -1.32231246e-01,
#        -1.04347925e-01, -1.24096136e-01, -1.19303853e-01, -5.83108422e-02,
#         6.55025946e-02, -4.83688763e-02, -3.77298971e-02, -1.69954954e-02,
#         1.08239663e-01, -1.03521522e-01,  4.42654071e-02,  3.71318532e-03,
#         5.60035634e-03,  7.71930481e-02, -3.16391674e-02, -1.40411352e-01,
#         2.35800039e-02, -1.01941079e-01,  2.97153956e-02, -1.36121385e-01,
#         3.60691763e-02, -4.18853284e-02,  5.83388416e-03, -7.67288319e-02,
#         4.77164008e-02, -5.83010557e-02, -1.14028819e-01, -4.79393922e-02,
#         1.24633346e-01,  5.20919055e-02,  4.87287080e-02, -1.08651793e-02,
#        -3.99381263e-02,  6.62327929e-02,  9.89379869e-02,  5.00415662e-03,
#         2.83254420e-01, -4.08614099e-02,  1.78746330e-01, -9.07328422e-02,
#         7.38945218e-02,  9.17911095e-03, -1.78689159e-01,  5.54638929e-02,
#         3.67017423e-02,  1.78679198e-02, -1.40212230e-01, -1.97695926e-03,
#         1.89623167e-01, -9.26959419e-02,  1.21170118e-02,  3.82505063e-02,
#         9.59565507e-02,  2.81043356e-02,  1.47231800e-01,  1.86656210e-01,
#         4.79286120e-02, -9.51170118e-02,  1.12482350e-01,  1.37840610e-01,
#         4.01370806e-01,  2.21292037e-01,  9.00790234e-04,  1.04325626e-03,
#        -3.59543945e-02,  3.38425018e-01,  1.40352998e-02,  6.26266025e-02,
#        -2.24910263e-01, -3.60705171e-02,  4.76843577e-02, -1.50814212e-01,
#        -4.17376035e-02, -1.39002349e-01,  6.13909498e-02, -6.20055133e-02,
#         5.65342811e-02, -1.10509188e-01,  9.76355838e-02,  4.10916774e-02])

# %% [markdown]
# ## Visualizaciones con librerías Matplotlib y Seaborn
# Ambas son para realizar visualizaciones. Existen muchas formas de visualizar datos estructurados en un vector o matriz. Los mas comunes son los histogramas, los mapas de calor, etc.

# %%
# importamos las librerias que nos serviran para visualizar
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Con "sns.distplot()" seaborn nos permite poder realizar un histograma y una aproximacion a la distribución de los datos en cuestion. En este caso realizaremos el distplot con el vector "normal_sample".

# %%
# generamos el distplot
sns.distplot(normal_sample)
plt.title("histograma del vector 'normal_sample' ")
plt.xlabel("valores de la variable aleatoria muestreada")
plt.ylabel("densidad de cada valor muestreado")
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_49932\309278116.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normal_sample)

# %% [markdown]
# Creamos otro vector proveniente de una normal con distinta media y desvio standard

# %%
# si generamos otro vector "normal_sample_2" con otra media y otro desvio standard
mu_2 = 0.5
sigma_2 = 0.2
# con las variables declaradas generamos un vector de 1000 posiciones
# cada posicion es un numero aleatorio extraido de una distribucion normal
normal_sample_2 = np.random.normal(mu_2, sigma_2, 1000)

# %%
# generamos el distplot
sns.distplot(normal_sample_2)
plt.title("histograma del vector 'normal_sample_2' ")
plt.xlabel("valores de la variable aleatoria muestreada")
plt.ylabel("densidad de cada valor muestreado")
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_49932\4236713047.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normal_sample_2)

# %% [markdown]
# Podriamos realizar en un mismo distplot la visualizacion de la densidad de los 2 vectores en simultáneo

# %%
# generamos el distplot, en una misma celda de codigo uno debajo del otro
# plt.show() imprime toda visualizacion que se haya acumulado en esa celda de codigo 
sns.distplot(normal_sample,label = "normal_sample", color = 'green')
sns.distplot(normal_sample_2, label = "normal_sample2", color = 'red')
plt.title("histograma de los dos vectores generados ")
plt.xlabel("valores de la variable aleatoria muestreada")
plt.ylabel("densidad de cada valor muestreado")
plt.legend()
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_49932\330375641.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normal_sample,label = "normal_sample", color = 'green')
# C:\Users\schas\AppData\Local\Temp\ipykernel_49932\330375641.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normal_sample_2, label = "normal_sample2", color = 'red')

# %% [markdown]
# **Scatter plot**
# Si consideramos ambos vectores como coordenadas y cada posicion una muestra (un punto) entonces tenemos 1000 muestras cada una caracterizada por 2 valores (o dimensiones). Dicho esto, podemos entonces visualizar las 1000 muestras caracterizadas por los 2 vectores provenientes cada uno de una distribucion normal con distintos parametros. El scatter plot visualiza nubes de puntos. Seaborn tiene una función para realizar scatter plots.

# %%
# utilizamos cada vector como una dimension, uno para el eje x y otro para el eje y.
sns.scatterplot(x= normal_sample, y= normal_sample_2)
plt.title("Ejemplo de scatterplot con seaborn")
plt.xlabel("valores de normal_sample")
plt.ylabel("valores de normal_sample_2")
plt.show()

# %% [markdown]
# Matplotlib es otra libreria que tambien tiene funciones similares, como scatter plot

# %%
# con el comando plt.scatter() ingresamos los 2 vectores para visualizar las 1000 muestras.
# el parametro "alpha" hace traslucidas las muestras que se solapan una encima de otra.
plt.scatter(normal_sample, normal_sample_2, alpha = 0.3)
plt.title("Ejemplo de scatterplot con matplotlib")
plt.xlabel("valores de normal_sample")
plt.ylabel("valores de normal_sample_2")
plt.show()

# %% [markdown]
# # Librería Pandas: Gestion de datos estructurados (tablas)
# Pandas es una importante libreria de python para manipular datos que esten en un formato de tablas (.csv, .txt, .xls). Con Pandas podremos importar datos obtenidos en los formatos mencionados, por ejemplo el portal de datos abiertos de la Ciudad de Buenos Aires. Puntualmente trabajaremos con los datos de Arbolado Publico Lineal del año 2011 obtenidos del siguiente enlace https://data.buenosaires.gob.ar/dataset/arbolado-publico-lineal.
# Una vez que descargues el dataset de arbolado 2011 guardalo en alguna carpeta de tu computadora y con click derecho "propiedades" fijate cual es la ruta de carpetas donde esta alojado el archivo .csv que descargaste.

# %%
# importamos la libreria pandas
import pandas as pd

# %% [markdown]
# El comando de pandas "pd.read_csv" permite importar archivos .csv alojados en la computadora  a jupyter. El archivo sera importado como una tabla con renglones (rows) y columnas (columns). A las tablas generadas desde Pandas las llamamos "DataFrame". Ver que el parametro que solicita el comando "pd.read_csv()" es la ruta de la carpeta donde esta alojado el archivo (la ruta incluye el nombre del archivo). Eso quiere decir que una vez que descarguen el archivo, lo guardaran en alguna carpeta que creas conveniente y luego obtendrás la ruta.
#
# **Aclaración usuarios windows:** en algunos casos de usuarios con windows, muchas veces se genera un error y es necesario agregar la letra "r" antes de la ruta (algo asi como pd.read_csv(r'Ruta donde el CSV esta guardado\nombre.csv')). Para mas información ver como importar archivos .csv en windows desde este blogpost https://datatofish.com/import-csv-file-python-using-pandas/

# %%
pwd
# Out:
# 'c:\\Users\\schas\\OneDrive - AlixPartners\\Santiago Chas\\clusterai\\ClusterAI_2026\\clase_0'

# %%
# importamos el archivo "arbolado2011.csv" y lo guardamos en la variable "arbolado".
arbolado = pd.read_csv('./arbolado-publico-lineal-2011.csv', header = 0, index_col = 'id_arbol')

# %%
# importamos el archivo "arbolado2011.csv" y lo guardamos en la variable "arbolado".
#arbolado = pd.read_csv(r"C:\Users\kevin.dobzewicz\Desktop\Ciencia-de-Datos-UTN-FRBA-main\clase00\arbolado-publico-lineal-2011.csv", header = 0, index_col = 'id_arbol')

# %% [markdown]
# #### Parte de las visualizaciones que observes en las próximas lineas fueron implementadas por los estudiantes de Ingeniería Industrial Agustin Tettamanti, Daniela Morini y Alejandra Zuñiga. Podrás encontrar el trabajo completo de ellos en https://github.com/atettamanti/TP-grupo-0

# %%
# averiguamos que tipo de variable es matrimonios: un DataFrame de Pandas.
type(arbolado)
# Out:
# pandas.core.frame.DataFrame

# %%
# Con np.shape() nos fijamos que dimension tiene el archivo (renglones, columnas)
np.shape(arbolado)
# Out:
# (372699, 19)

# %% [markdown]
# Al DataFrame "matrimonios" podemos solicitarle información como visualizar los primeros renglones agregando al nombre del dataframe el comando ".head()". Por default aparecen 5 renglones. Observaremos que además del contenido de cada registro de matrimonio, el dataframe se caracteriza por tener un indice (el nombre de cada renglon) y columnas (cada columna tiene un nombre).

# %%
# con .head() visualizamos los primeros 5 renglones del dataframe.
arbolado.tail(2)
# Out:
#                 long        lat tipo_sitio  altura_tot  diametro  inclinacio  \
# id_arbol
# 938000242 -58.493116 -34.623887      Árbol          10        58           0
# 938000243 -58.493086 -34.624042      Árbol           3         5           0
#
#            id_especie nombre_fam     nombre_gen            nombre_cie  \
# id_arbol
# 938000242           3  Meliáceas          Melia       Melia azeradach
# 938000243           8  Litráceas  Lagerstroemia  Lagerstroemia indica
#
#                            nombre_com                     tipo_folla   origen  \
# id_arbol
# 938000242                     Paraíso  Árbol Latifoliado Caducifolio  Exótico
# 938000243  Crespón (Àrbol de Júpiter)  Árbol Latifoliado Caducifolio  Exótico
#
#           codigo_man    barrio  comuna               calle  chapa1  chapa2
# id_arbol
# 938000242    79-005A  FLORESTA      10            Sanabria       0       0
# 938000243    79-005A  FLORESTA      10  Diaz, Cesar, Gral.       0       0

# %%
# podemos tambien acceder al listado de columnas 
arbolado.columns
# Out:
# Index(['long', 'lat', 'tipo_sitio', 'altura_tot', 'diametro', 'inclinacio',
#        'id_especie', 'nombre_fam', 'nombre_gen', 'nombre_cie', 'nombre_com',
#        'tipo_folla', 'origen', 'codigo_man', 'barrio', 'comuna', 'calle',
#        'chapa1', 'chapa2'],
#       dtype='object')

# %%
# tambien podemos acceder al vector de indices
arbolado.index
# Out:
# Index([     2430,      2431,      2432,      2433,      2434,      2435,
#             2436,      2437,      2438,      2440,
#        ...
#        938000234, 938000235, 938000236, 938000237, 938000238, 938000239,
#        938000240, 938000241, 938000242, 938000243],
#       dtype='int64', name='id_arbol', length=372699)

# %% [markdown]
# el vector de indices es impreso en pantalla como un elemento "RangeIndex" con comienzo en 0 y fin en 11732, que equivale a la cantidad de renglones. Python en algunos casos en vez de imprimir literalmente un vector que vaya de 0 a 11732 con incrementos de +1, utiliza el formato "range" indicando el inicio, fin y el "paso" entre cada registro.

# %% [markdown]
# #### Limpiar y pre-procesar los datos

# %%
# Vamos a ver cuantos elementos de cada columna tienen valores nulos (NaNs)
arbolado.isnull().sum()
# Out:
# long          0
# lat           0
# tipo_sitio    0
# altura_tot    0
# diametro      0
# inclinacio    0
# id_especie    0
# nombre_fam    0
# nombre_gen    0
# nombre_cie    0
# nombre_com    5
# tipo_folla    0
# origen        0
# codigo_man    0
# barrio        0
# comuna        0
# calle         0
# chapa1        0
# chapa2        0
# dtype: int64

# %%
# Con el comando .dropna() eliminamos todas las filas que tengan algún valor nulo 
arboles = arbolado.dropna()

# %%
# con .shape podemos ver el tamaño del dataframe por filas y columnas
arboles.shape
# Out:
# (372694, 19)

# %%
type(arbolado.isnull().sum().max())
# Out:
# numpy.int64

# %%
# imprimimos la cantidad de filas eliminadas
print("La cantidad de nulos eliminados de los datos es: "+ str(arbolado.isnull().sum().max()))
# Out:
# La cantidad de nulos eliminados de los datos es: 5

# %% [markdown]
# ### Visualizar dataframes con Seaborn y Matplotlib

# %%
plt.figure (figsize=(15,6))
ax = sns.countplot(x="barrio", data=arboles)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.title("Cantidad de árboles por barrio")
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_49932\3671450575.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
plt.figure (figsize=(15,6))
ax = sns.countplot(x="nombre_com", data=arboles)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.title("Cantidad de árboles por barrio")
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_49932\3136364314.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
print("El TOP5 de barrios con mayor cantidad de árboles es:                                                                           " 
      + str(arboles.barrio.value_counts(ascending=False).head()))
# Out:
# El TOP5 de barrios con mayor cantidad de árboles es:                                                                           barrio
# PALERMO         22483
# MATADEROS       18289
# VILLA DEVOTO    17537
# CABALLITO       15660
# FLORES          15278
# Name: count, dtype: int64

# %%
arboles.barrio.value_counts(ascending=False).head()
# Out:
# barrio
# PALERMO         22483
# MATADEROS       18289
# VILLA DEVOTO    17537
# CABALLITO       15660
# FLORES          15278
# Name: count, dtype: int64

# %%
arboles.barrio.value_counts(ascending=False).head()
# Out:
# barrio
# PALERMO         22483
# MATADEROS       18289
# VILLA DEVOTO    17537
# CABALLITO       15660
# FLORES          15278
# Name: count, dtype: int64

# %%
# imprimimos todos los valores posibles que pueden haber en la columna "tipo_folla"
print("tipo_folla")
print(arboles.tipo_folla.unique())
# Out:
# tipo_folla
# ['Árbol Latifoliado Caducifolio' 'Árbol Latifoliado Perenne'
#  'No Determinado' 'Arbusto Perenne' 'Árbol Conífero Perenne' 'Palmera'
#  'Arbusto o Herbacea' 'Arbusto Caducifolio' 'Árbol Conífero Caducifolio'
#  'Miscelaneo']

# %%
# Grafico de barras para contar cuantos arboles hay por tipo de folla
plt.figure(figsize=(15,6))
ax = sns.countplot(x="tipo_folla", data=arboles)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.title("Cantidad de árboles por tipo de hoja")
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_49932\2220465762.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
print("El TOP3 de cantidad de arboles por tipo de hoja son:                                                                           " 
      + str(arboles.tipo_folla.value_counts(ascending=False).head(3)))
# Out:
# El TOP3 de cantidad de arboles por tipo de hoja son:                                                                           tipo_folla
# Árbol Latifoliado Caducifolio    296880
# Árbol Latifoliado Perenne         56061
# No Determinado                    12761
# Name: count, dtype: int64

# %%
print("El TOP5 de cantidad de arboles por tipo de familia es:                                                                           " 
      + str(arboles.nombre_fam.value_counts(ascending=False).head()))
# Out:
# El TOP5 de cantidad de arboles por tipo de familia es:                                                                           nombre_fam
# Oleáceas       175247
# Platanaceae     35152
# Moráceas        27064
# Meliáceas       24681
# Leguminosas     22355
# Name: count, dtype: int64

# %%
# hacemos un grafico de barras para saber cuantos arboles hay por cada valor de la columna "origen"
plt.figure (figsize=(8,6))
ax = sns.countplot(x="origen", data=arboles)
plt.title("Cantidad de árboles por origen")
plt.show()

# %%
print("Cantidad de arboles por origen:"+str(arboles.origen.value_counts(ascending=False).head(3)))
# Out:
# Cantidad de arboles por origen:origen
# Exótico             334503
# Nativo/Autóctono     30410
# No Determinado        7781
# Name: count, dtype: int64

# %% [markdown]
# #### Vamos a visualizar la distribución de valores que tiene la variable altura para todo el dataset.

# %%
plt.figure(figsize=(10,3))
sns.distplot(arboles.altura_tot, color="Blue")
plt.xlabel("Altura")
plt.ylabel("Frecuency")
plt.title('Distribucion de la altura',size = 20)
plt.show()

plt.figure(figsize=(10,3))
sns.countplot(arboles.altura_tot, color="Blue")
plt.xlabel("Altura")
plt.ylabel("Count")
#plt.xticks([])
plt.show()
# Out:
# C:\Users\schas\AppData\Local\Temp\ipykernel_49932\4205882594.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(arboles.altura_tot, color="Blue")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 9
#       6 plt.show()
#       8 plt.figure(figsize=(10,3))
# ----> 9 sns.countplot(arboles.altura_tot, color="Blue")
#      10 plt.xlabel("Altura")
#      11 plt.ylabel("Count")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\categorical.py:2675, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2671     p.plot_data[count_axis] /= len(p.plot_data) / denom
#    2673 aggregator = EstimateAggregator("sum", errorbar=None)
# -> 2675 p.plot_bars(
#    2676     aggregator=aggregator,
#    2677     dodge=dodge,
#    2678     width=width,
#    2679     gap=gap,
#    2680     color=color,
#    2681     fill=fill,
#    2682     capsize=0,
#    2683     err_kws={},
#    2684     plot_kws=kwargs,
#    2685 )
#    2687 p._add_axis_labels(ax)
#    2688 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\categorical.py:1280, in _CategoricalPlotter.plot_bars(self, aggregator, dodge, gap, width, fill, color, capsize, err_kws, plot_kws)
#    1273 for sub_vars, sub_data in self.iter_data(iter_vars,
#    1274                                          from_comp_data=True,
#    1275                                          allow_empty=True):
#    1277     ax = self._get_axes(sub_vars)
#    1279     agg_data = sub_data if sub_data.empty else (
# -> 1280         sub_data
#    1281         .groupby(self.orient)
#    1282         .apply(aggregator, agg_var, **groupby_apply_include_groups(False))
#    1283         .reset_index()
#    1284     )
#    1286     agg_data["width"] = width * self._native_width
#    1287     if dodge:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\groupby\groupby.py:1819, in GroupBy.apply(self, func, include_groups, *args, **kwargs)
#    1816     f = func
#    1818 if not include_groups:
# -> 1819     return self._python_apply_general(f, self._obj_with_exclusions)
#    1821 # ignore SettingWithCopy here in case the user mutates
#    1822 with option_context("mode.chained_assignment", None):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\groupby\groupby.py:1885, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1850 @final
#    1851 def _python_apply_general(
#    1852     self,
#    (...)   1857     is_agg: bool = False,
#    1858 ) -> NDFrameT:
#    1859     """
#    1860     Apply function f in python space
#    1861
#    (...)   1883         data after applying f
#    1884     """
# -> 1885     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1886     if not_indexed_same is None:
#    1887         not_indexed_same = mutated
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\groupby\ops.py:919, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     917 # group might be modified
#     918 group_axes = group.axes
# --> 919 res = f(group)
#     920 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     921     mutated = True
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\groupby\groupby.py:1809, in GroupBy.apply.<locals>.f(g)
#    1807 @wraps(func)
#    1808 def f(g):
# -> 1809     return func(g, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\_statistics.py:492, in EstimateAggregator.__call__(self, data, var)
#     490     estimate = self.estimator(vals)
#     491 else:
# --> 492     estimate = vals.agg(self.estimator)
#     494 # Options that produce no error bars
#     495 if self.error_method is None:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:4777, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4774     func = dict(kwargs.items())
#    4776 op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4777 result = op.agg()
#    4778 return result
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\apply.py:1425, in SeriesApply.agg(self)
#    1424 def agg(self):
# -> 1425     result = super().agg()
#    1426     if result is None:
#    1427         obj = self.obj
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\apply.py:187, in Apply.agg(self)
#     184 kwargs = self.kwargs
#     186 if isinstance(func, str):
# --> 187     return self.apply_str()
#     189 if is_dict_like(func):
#     190     return self.agg_dict_like()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\apply.py:581, in Apply.apply_str(self)
#     579 method = getattr(obj, func, None)
#     580 if callable(method):
# --> 581     sig = inspect.getfullargspec(method)
#     582     arg_names = (*sig.args, *sig.kwonlyargs)
#     583     if self.axis != 0 and (
#     584         "axis" not in arg_names or func in ("corrwith", "skew")
#     585     ):
#
# File c:\Program Files\Python313\Lib\inspect.py:1378, in getfullargspec(func)
#    1346 """Get the names and default values of a callable object's parameters.
#    1347
#    1348 A tuple of seven things is returned:
#    (...)   1359   - wrapper chains defined by __wrapped__ *not* unwrapped automatically
#    1360 """
#    1361 try:
#    1362     # Re: `skip_bound_arg=False`
#    1363     #
#    (...)   1375     # getfullargspec() historically ignored __wrapped__ attributes,
#    1376     # so we ensure that remains the case in 3.3+
# -> 1378     sig = _signature_from_callable(func,
#    1379                                    follow_wrapper_chains=False,
#    1380                                    skip_bound_arg=False,
#    1381                                    sigcls=Signature,
#    1382                                    eval_str=False)
#    1383 except Exception as ex:
#    1384     # Most of the times 'signature' will raise ValueError.
#    1385     # But, it can also raise AttributeError, and, maybe something
#    1386     # else. So to be fully backwards compatible, we catch all
#    1387     # possible exceptions here, and reraise a TypeError.
#    1388     raise TypeError('unsupported callable') from ex
#
# File c:\Program Files\Python313\Lib\inspect.py:2531, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2526     raise TypeError('{!r} is not a callable object'.format(obj))
#    2528 if isinstance(obj, types.MethodType):
#    2529     # In this case we skip the first parameter of the underlying
#    2530     # function (usually `self` or `cls`).
# -> 2531     sig = _get_signature_of(obj.__func__)
#    2533     if skip_bound_arg:
#    2534         return _signature_bound_method(sig)
#
# File c:\Program Files\Python313\Lib\inspect.py:2605, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2600     return _signature_get_partial(wrapped_sig, obj)
#    2602 if isfunction(obj) or _signature_is_functionlike(obj):
#    2603     # If it's a pure Python function, or an object that is duck type
#    2604     # of a Python function (Cython functions, for instance), then:
# -> 2605     return _signature_from_function(sigcls, obj,
#    2606                                     skip_bound_arg=skip_bound_arg,
#    2607                                     globals=globals, locals=locals, eval_str=eval_str)
#    2609 if _signature_is_builtin(obj):
#    2610     return _signature_from_builtin(sigcls, obj,
#    2611                                    skip_bound_arg=skip_bound_arg)
#
# File c:\Program Files\Python313\Lib\inspect.py:2428, in _signature_from_function(cls, func, skip_bound_arg, globals, locals, eval_str)
#    2426 keyword_only_count = func_code.co_kwonlyargcount
#    2427 keyword_only = arg_names[pos_count:pos_count + keyword_only_count]
# -> 2428 annotations = get_annotations(func, globals=globals, locals=locals, eval_str=eval_str)
#    2429 defaults = func.__defaults__
#    2430 kwdefaults = func.__kwdefaults__
#
# File c:\Program Files\Python313\Lib\inspect.py:251, in get_annotations(obj, globals, locals, eval_str)
#     246 elif callable(obj):
#     247     # this includes types.Function, types.BuiltinFunctionType,
#     248     # types.BuiltinMethodType, functools.partial, functools.singledispatch,
#     249     # "class funclike" from Lib/test/test_inspect... on and on it goes.
#     250     ann = getattr(obj, '__annotations__', None)
# --> 251     obj_globals = getattr(obj, '__globals__', None)
#     252     obj_locals = None
#     253     unwrap = obj
#
# KeyboardInterrupt:

# %% [markdown]
# #### Vamos a visualizar la distribución de valores que tiene la variable diametro en todo el dataset

# %%
plt.figure(figsize=(10,3))
sns.distplot(arboles.diametro, color="Green")
plt.xlabel("Diametro")
plt.ylabel("Frecuency")
plt.title('Distribucion del diametro',size = 20)
plt.show()
# Out:
# C:\Users\kevin.dobzewicz\AppData\Local\Temp\ipykernel_36504\3001448137.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(arboles.diametro, color="Green")

# %% [markdown]
# #### Realizaremos un boxplot para entender la distribución en quantiles de la altura por barrio

# %%
g = sns.catplot(x="barrio",y="altura_tot",data=arboles, kind="box", height = 5 ,aspect=3,palette = "muted")
g.despine(left=False) # Para quitar los el eje Y del plot
g.set_xticklabels(rotation=90)

plt.xlabel("Familia")
plt.ylabel("Altura")
plt.title('Boxplot de Altura VS Familia',size = 12)
plt.show()
# Out:
# C:\Users\kevin.dobzewicz\AppData\Local\Temp\ipykernel_36504\707583045.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(x="barrio",y="altura_tot",data=arboles, kind="box", height = 5 ,aspect=3,palette = "muted")

# %% [markdown]
# #### El pairplot ayuda a entender como co-varian cada par de variables y así poder visualizar si existe o no algún tipo de correlación
# En este caso solo lo realizaremos para las variables
# - Diametro
# - Altura
# - Inclinación

# %%
sns.pairplot(arboles[["diametro", "altura_tot", "inclinacio"]])
plt.show()

# %% [markdown]
# #### Ahora generamos una matriz de correlación entre pares de variables y la aplicamos las mismas variables del punto anterior

# %%
#arboles[["diametro", "altura_tot", "inclinacio"]]

# %%
#Se observa una correlacion lineal bastante fuerte entre Altura y Diámetro
corrmat = arboles[["diametro", "altura_tot", "inclinacio"]].corr()
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
corrmat
# Out:
#             diametro  altura_tot  inclinacio
# diametro    1.000000    0.653080    0.057734
# altura_tot  0.653080    1.000000    0.101717
# inclinacio  0.057734    0.101717    1.000000

# %%
type(corrmat)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Funciones en python
# Supongamos que queremos utilizar muchas veces un mismo segmento de codigo. En vez de repetirlo multiples veces, podemos crear funciones de python. Cada vez que necesitamos realizar dicha acción llamamos a la función. Vamos a crear una función para imprimir el valor de una posición dentro de un pandas dataframe.

# %%
# Las funciones deben declararse con "def + nombre de la funcion" y entre (input)
def imprimir_dato(dato):
    
    return print("El dato en cuestion es " + str(dato))

# %%
arboles.nombre_fam.values[2]
# Out:
# 'Oleáceas'

# %% [markdown]
# Podriamos usar la función definida para situaciones puntuales, por ejemplo para el tercer registro del dataframe "arboles". Recordemos que si hablamos del tercer elemento entonces su indice será el 2, ya que en Python los índices comienzan en 0.

# %%
imprimir_dato(arboles.nombre_fam.values[2])
# Out:
# El dato en cuestion es Oleáceas

# %% [markdown]
# # For loops
# Muchas veces vamos a necesitar iterar sobre una matriz o vector para realizar alguna operación particular. Esto se puede lograr mediante los loops "for". El mismo debe definir un elemento iterador que cambiará de valor en cada paso del loop. En el ejemplo el iterador será la variable "i" y su rango de iteración será desde 0 a 4. El rango va de 0 a 5 indicando el valor de comienzo y el valor final-1 (así es la sintaxis de python).

# %%
for i in range(0,15):
    imprimir_dato(arboles.nombre_fam.values[i])
# Out:
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Aceráceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Rosáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Moráceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas
# El dato en cuestion es Oleáceas

# %%
arboles.nombre_fam.values[0:15]
# Out:
# array(['Oleáceas', 'Oleáceas', 'Oleáceas', 'Aceráceas', 'Oleáceas',
#        'Rosáceas', 'Oleáceas', 'Oleáceas', 'Oleáceas', 'Oleáceas',
#        'Moráceas', 'Oleáceas', 'Oleáceas', 'Oleáceas', 'Oleáceas'],
#       dtype=object)

# %% [markdown]
# De esta manera generamos un loop de 15 iteraciones que imprime el valor de la comuna en la posicion "i" del vector "comunas"

# %% [markdown]
# **Lo lograste!**
# Si llegaste a este punto quiere decir que pudiste ejecutar:
# - Abrir un Jupyter notebook exitosamente.
# - Operaciones básicas en Python como print o suma.
# - Utilizar Numpy para crear arrays y realizar operaciones con ellos.
# - Utilizar Numpy para crear vectores provenientes de distribuciones normales de probabilidad.
# - Visualización con matplotlib y seaborn para hacer Scatter, Distplot, Countplot.
# - Importar archivos .csv con Pandas
# - Filtrar por columnas con Pandas
# - Crear funciones de Python
# - Generar for loops

# %% [markdown]
# **Como seguir:** Queda mucho por hacer aunque lograr ejecutar este notebook fue un gran logro. Te invitamos a que trates de comprender el paso a paso, amigarte con la sintaxis y modificar algunas variables clave en cada ejercicio para obtener otros resultados.
